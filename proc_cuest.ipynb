# %% [markdown]
# Búsqueda, descarga preparación de encuestas de Los Mexicanos

# %%
# ruta encuestas
ruta_enc= '/Users/salvadorVMA/Google Drive/01 Proyectos/2025/navegador/encuestas'

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import re
import time

base_url = "http://www.losmexicanos.unam.mx/"
domain = urlparse(base_url).netloc
pattern = re.compile(r'\.(pdf|dat|sav)$', re.IGNORECASE)

visited_pages = set()
found_files = set()

def crawl(url, delay=0.5):
    if url in visited_pages:
        return
    visited_pages.add(url)
    
    try:
        response = requests.get(url)
        response.raise_for_status()
    except Exception as e:
        print(f"Error accessing {url}: {e}")
        return

    # Only parse HTML pages
    content_type = response.headers.get("Content-Type", "")
    if "text/html" not in content_type:
        return

    soup = BeautifulSoup(response.text, "html.parser")
    
    # Check all links on the page
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        full_url = urljoin(url, href)
        parsed_href = urlparse(full_url)

        # Skip if not on same domain
        if parsed_href.netloc != domain:
            continue

        # If link is a file link, add it
        if pattern.search(full_url):
            found_files.add(full_url)
        else:
            # Otherwise crawl the page if not already visited
            # You could restrict file extensions to only common page types (e.g., .html, .php) if needed.
            if full_url not in visited_pages:
                crawl(full_url, delay)
    
    # Optionally delay between requests so as not to overwhelm the server
    time.sleep(delay)

crawl(base_url)



print("Found file URLs:")
for file_url in found_files:
    print(file_url)

found_files = list(found_files)
# Out:
# Error accessing http://www.losmexicanos.unam.mx/juegosazar/prologo.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/juegosazar/prologo.html
# Error accessing http://www.losmexicanos.unam.mx/nota_preliminar.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/nota_preliminar.html
# Error accessing http://www.losmexicanos.unam.mx/presentacion.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/presentacion.html
# Error accessing http://www.losmexicanos.unam.mx/perfil_encuestados.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/perfil_encuestados.html
# Error accessing http://www.losmexicanos.unam.mx/autores.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/autores.html
# Error accessing http://www.losmexicanos.unam.mx/indice.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/indice.html
# Error accessing http://www.losmexicanos.unam.mx/encuesta_nacional.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/encuesta_nacional.html
# Error accessing http://www.losmexicanos.unam.mx/libro/index.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/libro/index.html
# Error accessing http://www.losmexicanos.unam.mx/introduccion.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/introduccion.html
# Error accessing http://www.losmexicanos.unam.mx/corrupcionyculturadelalegalidad/encuesta_nacional/base_datos/Encuesta_Nacional_de_CorrupciÃ³n_y_Cultura_de_la_Legalidad.dta: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/corrupcionyculturadelalegalidad/encuesta_nacional/base_datos/Encuesta_Nacional_de_Corrupci%C3%83%C2%B3n_y_Cultura_de_la_Legalidad.dta
# Error accessing http://www.losmexicanos.unam.mx/niÃ±osadolescentesyjovenes/index.html: 404 Client Error: Not Found for url: http://www.losmexicanos.unam.mx/ni%C3%83%C2%B1osadolescentesyjovenes/index.html
# Found file URLs:
# http://www.losmexicanos.unam.mx/identidadyvalores/encuesta_nacional/base_datos/Encuesta_Nacional_de_Identidad_y_Valores.sav
# http://www.losmexicanos.unam.mx/justicia/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Justicia.pdf
# http://www.losmexicanos.unam.mx/migracion/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Migracion.pdf
# http://www.losmexicanos.unam.mx/juegosazar/encuesta_nacional/vivienda/cuestionario/cuestionario.pdf
# http://www.losmexicanos.unam.mx/medioambiente/encuesta_nacional/base_datos/Encuesta_Nacional_de_Medio_Ambiente.sav
# http://www.losmexicanos.unam.mx/pobreza/encuesta_nacional/base_datos/Encuesta_Nacional_de_Pobreza.sav
# http://www.losmexicanos.unam.mx/culturapolitica/encuesta_nacional/base_datos/Encuesta_Nacional_de_Cultura_Politica.sav
# http://www.losmexicanos.unam.mx/medioambiente/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Medio_Ambiente.pdf
# http://www.losmexicanos.unam.mx/salud/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Salud.pdf
# http://www.losmexicanos.unam.mx/movilidadytransporte/encuesta_nacional/base_datos/Encuesta_Nacional_de_ Movilidad_y_Transporte_Automoviles.sav
# http://www.losmexicanos.unam.mx/corrupcionyculturadelalegalidad/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Corrupcion_y_Cultura_de_la_Legalidad.pdf
# http://www.losmexicanos.unam.mx/culturalecturaydeporte/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Cultura_Lectura_y_Deporte.pdf
# http://www.losmexicanos.unam.mx/religion/encuesta_nacional/base_datos/Encuesta_Nacional_de_Religion_Secularizacion_y_Laicidad.sav
# http://www.losmexicanos.unam.mx/MexicanosConstitucion/encuesta_nacional/metodologia/metodologia.pdf
# http://www.losmexicanos.unam.mx/seguridadpublica/encuesta_nacional/base_datos/Encuesta_Nacional_de_Seguridad_Publica.sav
# http://www.losmexicanos.unam.mx/seguridadpublica/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Seguridad_Publica.pdf
# http://www.losmexicanos.unam.mx/salud/encuesta_nacional/base_datos/Encuesta_Nacional_de_Salud.sav
# http://www.losmexicanos.unam.mx/familia/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Familia_Seccion_Hogar.pdf
# http://www.losmexicanos.unam.mx/juegosazar/encuesta_nacional/en_linea/metodologia/metodologia.pdf
# http://www.losmexicanos.unam.mx/culturapolitica/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Cultura_Politica.pdf
# http://www.losmexicanos.unam.mx/indigenas/encuesta_nacional/base_datos/Encuesta_Nacional_de_Indigenas.sav
# http://www.losmexicanos.unam.mx/sociedaddelainformacion/encuesta_nacional/base_datos/Encuesta_Nacional_de_Sociedad_de_la_Informacion.sav
# http://www.losmexicanos.unam.mx/MexicanosConstitucion/pdf/Mexicanos_Constitucion.pdf
# http://www.losmexicanos.unam.mx/envejecimiento/encuesta_nacional/base_datos/Encuesta_Nacional_de_Envejecimiento.sav
# http://www.losmexicanos.unam.mx/envejecimiento/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Envejecimiento.pdf
# http://www.losmexicanos.unam.mx/derechoshumanos/encuesta_nacional/base_datos/Encuesta_Nacional_de_Derechos_Humanos_Discriminacion_y_Grupos_Vulnerables.sav
# http://www.losmexicanos.unam.mx/corrupcionyculturadelalegalidad/encuesta_nacional/base_datos/Encuesta_Nacional_de_Corrupcion_y_Cultura_de_la_Legalidad.sav
# http://www.losmexicanos.unam.mx/federalismo/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Federalismo.pdf
# http://www.losmexicanos.unam.mx/vivienda/encuesta_nacional/base_datos/Encuesta_Nacional_sobre_la_Condicion_de_Habitabilidad_de_Vivienda_en_Mexico.sav
# http://www.losmexicanos.unam.mx/cienciaytecnologia/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Ciencia_y_Tecnologia.pdf
# http://www.losmexicanos.unam.mx/globalizacion/encuesta_nacional/base_datos/Encuesta_Nacional_de_Globalizacion.sav
# http://www.losmexicanos.unam.mx/juegosazar/encuesta_nacional/en_linea/base_datos/encuesta-en-linea.sav
# http://www.losmexicanos.unam.mx/justicia/encuesta_nacional/base_datos/Encuesta_Nacional_de_Justicia.sav
# http://www.losmexicanos.unam.mx/genero/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Genero.pdf
# http://www.losmexicanos.unam.mx/movilidadytransporte/encuesta_nacional/base_datos/Encuesta_Nacional_de_Movilidad_y_Transporte.sav
# http://www.losmexicanos.unam.mx/juegosazar/encuesta_nacional/vivienda/base_datos/encuesta-nacional-en-vivienda-juegos-de-azar.sav
# http://www.losmexicanos.unam.mx/migracion/encuesta_nacional/base_datos/Encuesta_Nacional_de_Migracion.sav
# http://www.losmexicanos.unam.mx/movilidadytransporte/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Movilidad_y_Transporte_Seccion_Hogar.pdf
# http://www.losmexicanos.unam.mx/movilidadytransporte/encuesta_nacional/base_datos/Encuesta_Nacional_de_Movilidad_y_Transporte_Viajes.sav
# http://www.losmexicanos.unam.mx/globalizacion/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Globalizacion.pdf
# http://www.losmexicanos.unam.mx/federalismo/encuesta_nacional/base_datos/Encuesta_Nacional_de_Federalismo.sav
# http://www.losmexicanos.unam.mx/genero/encuesta_nacional/base_datos/Encuesta_Nacional_de_Genero.sav
# http://www.losmexicanos.unam.mx/MexicanosConstitucion/encuesta_nacional/base_datos/Tercera_Encuesta_Nacional_de_Cultura_Constitucional.sav
# http://www.losmexicanos.unam.mx/educacion/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Educacion.pdf
# http://www.losmexicanos.unam.mx/culturalecturaydeporte/encuesta_nacional/base_datos/Encuesta_Nacional_de_Cultura_Lectura_y_Deporte.sav
# http://www.losmexicanos.unam.mx/economiayempleo/encuesta_nacional/base_datos/Encuesta_Nacional_de_Economia_y_Empleo.sav
# http://www.losmexicanos.unam.mx/ninosadolescentesyjovenes/encuesta_nacional/base_datos/Encuesta_Nacional_de_Ninos_Adolescentes_y_Jovenes.sav
# http://www.losmexicanos.unam.mx/derechoshumanos/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Derechos_Humanos_y_Grupos_Vulnerables.pdf
# http://www.losmexicanos.unam.mx/indigenas/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Indigenas.pdf
# http://www.losmexicanos.unam.mx/familia/encuesta_nacional/base_datos/Encuesta_Nacional_de_Familia.sav
# http://www.losmexicanos.unam.mx/juegosazar/encuesta_nacional/vivienda/metodologia/metodologia.pdf
# http://www.losmexicanos.unam.mx/vivienda/encuesta_nacional/cuestionario/Encuesta_Nacional_Condicion_de_Habitabilidad_de_Vivienda_en_Mexico.pdf
# http://www.losmexicanos.unam.mx/ninosadolescentesyjovenes/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Ninos_Adolescentes_y_Jovenes.pdf
# http://www.losmexicanos.unam.mx/familia/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Familia.pdf
# http://www.losmexicanos.unam.mx/religion/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Religion_Secularizacion_y_Laicidad.pdf
# http://www.losmexicanos.unam.mx/juegosazar/encuesta_nacional/en_linea/cuestionario/cuestionario-para-jugadores-en-linea.pdf
# http://www.losmexicanos.unam.mx/movilidadytransporte/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Movilidad_y_Transporte.pdf
# http://www.losmexicanos.unam.mx/sociedaddelainformacion/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Sociedad_de_la_Informacion.pdf
# http://www.losmexicanos.unam.mx/pobreza/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Pobreza.pdf
# http://www.losmexicanos.unam.mx/economiayempleo/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Economia_y_Empleo.pdf
# http://www.losmexicanos.unam.mx/cienciaytecnologia/encuesta_nacional/base_datos/Encuesta_Nacional_de_Ciencia_y_Tecnologia.sav
# http://www.losmexicanos.unam.mx/educacion/encuesta_nacional/base_datos/Encuesta_Nacional_de_Educacion.sav
# http://www.losmexicanos.unam.mx/MexicanosConstitucion/encuesta_nacional/cuestionario/Tercera_Encuesta_Nacional_de_Cultura_Constitucional.pdf
# http://www.losmexicanos.unam.mx/pdf/metodologia.pdf
# http://www.losmexicanos.unam.mx/identidadyvalores/encuesta_nacional/cuestionario/Encuesta_Nacional_de_Identidad_y_Valores.pdf

# %%
import pyreadstat
import os  # newly added to handle file paths

noms_bases = [nom for nom in found_files if nom.endswith('.sav') and 'Movilidad' not in nom and 'linea' not in nom]
  
enc_dict = {}
for link in noms_bases:
    filename = link.split("/")[-1]
    print(f"Downloading and processing: {filename}")
    
    # Download the file
    response = requests.get(link)
    response.raise_for_status()
    
    # Save the file locally
    with open(os.path.join(ruta_enc, filename), "wb") as file_out:  # modified to save in ruta_enc
        file_out.write(response.content)
    
    # Read the .sav file
    df, meta = pyreadstat.read_sav(os.path.join(ruta_enc, filename))
    
    filename = filename.replace('-', '_').replace(' ', '_')

    prefix_lst = ["Tercera_Encuesta_Nacional_de_" , "Encuesta_Nacional_sobre_" , "Encuesta_Nacional_de_" , "encuesta-nacional-", "encuesta_nacional_en_vivienda_"]

    prefix = ""
    for p in prefix_lst:
        if filename.startswith(p):
            prefix = p
            break

    if filename.startswith(prefix):
        trimmed = filename[len(prefix):]
    else:
        trimmed = filename
    new_base = "_".join(trimmed.split()[:3])
    filename = f"{new_base}"

    meta = {
        "variable_value_labels": meta.variable_value_labels,
        "column_names_to_labels": meta.column_names_to_labels
    }

    # Store the dataframe and metadata in the dictionary
    enc_dict[filename] = {"dataframe": df, "metadata": meta}

enc_dict = {key.replace('.sav', ''): value for key, value in enc_dict.items()}
# Out:
# Downloading and processing: Encuesta_Nacional_de_Identidad_y_Valores.sav
# Downloading and processing: Encuesta_Nacional_de_Medio_Ambiente.sav
# Downloading and processing: Encuesta_Nacional_de_Medio_Ambiente.sav
# Downloading and processing: Encuesta_Nacional_de_Pobreza.sav
# Downloading and processing: Encuesta_Nacional_de_Pobreza.sav
# Downloading and processing: Encuesta_Nacional_de_Cultura_Politica.sav
# Downloading and processing: Encuesta_Nacional_de_Cultura_Politica.sav
# Downloading and processing: Encuesta_Nacional_de_Religion_Secularizacion_y_Laicidad.sav
# Downloading and processing: Encuesta_Nacional_de_Religion_Secularizacion_y_Laicidad.sav
# Downloading and processing: Encuesta_Nacional_de_Seguridad_Publica.sav
# Downloading and processing: Encuesta_Nacional_de_Seguridad_Publica.sav
# Downloading and processing: Encuesta_Nacional_de_Salud.sav
# Downloading and processing: Encuesta_Nacional_de_Salud.sav
# Downloading and processing: Encuesta_Nacional_de_Indigenas.sav
# Downloading and processing: Encuesta_Nacional_de_Indigenas.sav
# Downloading and processing: Encuesta_Nacional_de_Sociedad_de_la_Informacion.sav
# Downloading and processing: Encuesta_Nacional_de_Sociedad_de_la_Informacion.sav
# Downloading and processing: Encuesta_Nacional_de_Envejecimiento.sav
# Downloading and processing: Encuesta_Nacional_de_Envejecimiento.sav
# Downloading and processing: Encuesta_Nacional_de_Derechos_Humanos_Discriminacion_y_Grupos_Vulnerables.sav
# Downloading and processing: Encuesta_Nacional_de_Derechos_Humanos_Discriminacion_y_Grupos_Vulnerables.sav
# Downloading and processing: Encuesta_Nacional_de_Corrupcion_y_Cultura_de_la_Legalidad.sav
# Downloading and processing: Encuesta_Nacional_de_Corrupcion_y_Cultura_de_la_Legalidad.sav
# Downloading and processing: Encuesta_Nacional_sobre_la_Condicion_de_Habitabilidad_de_Vivienda_en_Mexico.sav
# Downloading and processing: Encuesta_Nacional_sobre_la_Condicion_de_Habitabilidad_de_Vivienda_en_Mexico.sav
# Downloading and processing: Encuesta_Nacional_de_Globalizacion.sav
# Downloading and processing: Encuesta_Nacional_de_Globalizacion.sav
# Downloading and processing: Encuesta_Nacional_de_Justicia.sav
# Downloading and processing: Encuesta_Nacional_de_Justicia.sav
# Downloading and processing: encuesta-nacional-en-vivienda-juegos-de-azar.sav
# Downloading and processing: encuesta-nacional-en-vivienda-juegos-de-azar.sav
# Downloading and processing: Encuesta_Nacional_de_Migracion.sav
# Downloading and processing: Encuesta_Nacional_de_Migracion.sav
# Downloading and processing: Encuesta_Nacional_de_Federalismo.sav
# Downloading and processing: Encuesta_Nacional_de_Federalismo.sav
# Downloading and processing: Encuesta_Nacional_de_Genero.sav
# Downloading and processing: Encuesta_Nacional_de_Genero.sav
# Downloading and processing: Tercera_Encuesta_Nacional_de_Cultura_Constitucional.sav
# Downloading and processing: Tercera_Encuesta_Nacional_de_Cultura_Constitucional.sav
# Downloading and processing: Encuesta_Nacional_de_Cultura_Lectura_y_Deporte.sav
# Downloading and processing: Encuesta_Nacional_de_Cultura_Lectura_y_Deporte.sav
# Downloading and processing: Encuesta_Nacional_de_Economia_y_Empleo.sav
# Downloading and processing: Encuesta_Nacional_de_Economia_y_Empleo.sav
# Downloading and processing: Encuesta_Nacional_de_Ninos_Adolescentes_y_Jovenes.sav
# Downloading and processing: Encuesta_Nacional_de_Ninos_Adolescentes_y_Jovenes.sav
# Downloading and processing: Encuesta_Nacional_de_Familia.sav
# Downloading and processing: Encuesta_Nacional_de_Familia.sav
# Downloading and processing: Encuesta_Nacional_de_Ciencia_y_Tecnologia.sav
# Downloading and processing: Encuesta_Nacional_de_Ciencia_y_Tecnologia.sav
# Downloading and processing: Encuesta_Nacional_de_Educacion.sav
# Downloading and processing: Encuesta_Nacional_de_Educacion.sav

# %%
# enc_dict a pickle
import pickle
import os  # newly added to handle file paths

with open('encs.pkl', 'wb') as f:
    pickle.dump(enc_dict, open(os.path.join(ruta_enc, 'encs.pkl'), 'wb'))

# %%
# Get the first URL in found_files that ends with .sav
sav_url = next(url for url in found_files if url.lower().endswith('.sav'))
print("Downloading:", sav_url)

# Download the file
response = requests.get(sav_url)
response.raise_for_status()  # Ensure the request was successful

# Extract the filename from the URL
sav_filename = sav_url.split("/")[-1]

# Save the file locally
with open(os.path.join(ruta_enc, sav_filename), "wb") as file_out:  # modified to save in ruta_enc
    file_out.write(response.content)
print("Downloaded", sav_filename)

# Examine the SPSS file metadata using pyreadstat

# read_sav returns the DataFrame and the metadata
df, meta = pyreadstat.read_sav(sav_filename)

# Display some metadata information
print("Metadata column names:")
print(meta.column_names)
print("\nVariable labels:")
print(meta.variable_value_labels)
# Out:
# Downloading: http://www.losmexicanos.unam.mx/MexicanosConstitucion/encuesta_nacional/base_datos/Tercera_Encuesta_Nacional_de_Cultura_Constitucional.sav
# Downloaded Tercera_Encuesta_Nacional_de_Cultura_Constitucional.sav
# Metadata column names:
# ['ID_BASE', 'EDO', 'MUNI', 'LOC', 'AGEB', 'FOLIO', 'DIA_1', 'MES_1', 'HR_INI_1_1', 'HR_FIN_1_1', 'DURA_1', 'RESUL_1', 'DIA_2', 'MES_2', 'HR_INI_2_1', 'HR_FIN_2_1', 'DURA_2', 'RESUL_2', 'DIA_3', 'MES_3', 'HR_INI_3_1', 'HR_FIN_3_1', 'DURA_3', 'RESUL_3', 'DIA_4', 'MES_4', 'HR_INI_4_1', 'HR_FIN_4_1', 'DURA_4', 'RESUL_4', 'DIA_5', 'MES_5', 'DIA_6', 'MES_6', 'DIA_7', 'MES_7', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7_1', 'P7_2', 'P7_3', 'P8_1', 'P8_2', 'P8_3', 'P8_4', 'P9_1', 'P9_1a_1', 'P9_2', 'P9_2a_1', 'P9_3', 'P9_3a_1', 'P10', 'P10a_1', 'P11', 'P11a_1', 'P12_1', 'P12_2', 'P12_3', 'P12_4', 'P12_5', 'P13_1', 'P13_2', 'P13_3', 'P13_4', 'P13_5', 'P13_6', 'P13_7', 'P13_8', 'P13_9', 'P13_10', 'P13_11', 'P13_12', 'P13_13', 'P13_14', 'P13_15', 'P13_16', 'P13_17', 'P13_18', 'P13_19', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20', 'P20A', 'P21', 'P22', 'P22a_1', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P28A', 'P28Aa_1', 'P29', 'P30', 'P31', 'P32', 'P33_1', 'P33_2', 'P33_3', 'P34', 'P35_1', 'P35_2', 'P35_3', 'P35_4', 'P35_5', 'P35_6', 'P35_7', 'P36', 'P36a_1', 'P37_1', 'P37_2', 'P38', 'P39_1', 'P39_1a_1', 'P39_2', 'P39_2a_1', 'P39_3', 'P39_3a_1', 'P40_1', 'P40_1a_1', 'P40_2', 'P40_2a_1', 'P40_3', 'P40_3a_1', 'P41', 'P42', 'P42a_1', 'P43', 'P43a_1', 'P44', 'P45_1', 'P45_1a_1', 'P45_2', 'P45_2a_1', 'P45_3', 'P45_3a_1', 'P46_1', 'P46_1a_1', 'P46_2', 'P46_2a_1', 'P46_3', 'P46_3a_1', 'P47', 'P48', 'P49', 'P50', 'P51', 'P52', 'P53_1', 'P53_2', 'P53_3', 'P53_4', 'P53_5', 'P53_6', 'P53_7', 'P53_8', 'P53_9', 'P53_10', 'P54_1', 'P54_2', 'P54_3', 'P54_4', 'P54_5', 'P54_6', 'P54_7', 'P54_8', 'P55_1_1', 'P55_1_2', 'P55_1_3', 'P55_2_1', 'P55_2_2', 'P55_2_3', 'P55_3_1', 'P55_3_2', 'P55_3_3', 'P55_4_1', 'P55_4_2', 'P55_4_3', 'P55_5_1', 'P55_5_2', 'P55_5_3', 'P55_6_1', 'P55_6_2', 'P55_6_3', 'P55_7_1', 'P55_7_2', 'P55_7_3', 'P56', 'P57', 'P58', 'P59', 'P60', 'P61', 'P62', 'P63', 'P64', 'P65', 'P66', 'P67', 'P68', 'P69', 'P70', 'P71', 'P72', 'P73', 'P74', 'P75_1', 'P75_2', 'P75_3', 'P75_4', 'P76', 'P76A', 'P77', 'P78', 'P79', 'P80', 'P81', 'P82', 'P83', 'P84_1', 'P84_2', 'P84_3', 'P84_4', 'P84_5', 'P84_6', 'P84_7', 'P84_8', 'P85', 'P86', 'P87', 'P88', 'P89', 'P90', 'P91_1', 'P91_2', 'P91_3', 'P91_4', 'P91_5', 'P91_6', 'P91_7', 'P91_8', 'P91_9', 'P91_10', 'P91_11', 'P91_12', 'P91_13', 'P91_14', 'P91_15', 'P92', 'P93', 'P94', 'P95', 'S1', 'S2', 'S3_1', 'S3_2', 'S4', 'S5', 'S6', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'OBS', 'Pondi2', 'total2', 'sexo', 'edad', 'escol', 'region', 'ing_ind', 'ing_fam', 'partido_pol', 'est_civil', 'cond_act']
#
# Variable labels:
# {'P1': {1.0: ' Mejor', 2.0: ' Peor', 3.0: ' Igual de bien', 4.0: ' Igual de mal', 8.0: ' NS', 9.0: ' NC'}, 'P2': {1.0: ' Prometedora', 2.0: ' Preocupante', 3.0: ' Tranquila', 4.0: ' Peligrosa', 5.0: ' Con oportunidades', 6.0: ' Mejor que antes', 7.0: ' Más o menos', 8.0: ' Peor que antes', 9.0: ' Otra', 98.0: ' NS', 99.0: ' NC'}, 'P3': {1.0: ' Va a mejorar', 2.0: ' Va a empeorar', 3.0: ' Va a seguir igual de bien', 4.0: ' Va a seguir igual de mal', 8.0: ' NS', 9.0: ' NC'}, 'P4': {1.0: ' Mucho', 2.0: ' Algo', 3.0: ' Poco', 4.0: ' Nada', 8.0: ' NS', 9.0: ' NC'}, 'P5': {1.0: ' Siempre', 2.0: ' Nunca', 3.0: ' A veces', 4.0: ' Sólo en ocasiones muy especiales', 8.0: ' NS', 9.0: ' NC'}, 'P6': {1.0: ' Televisión', 2.0: ' Radio', 3.0: ' Internet', 4.0: ' Periódicos', 5.0: ' Revistas', 6.0: ' Amigos y conocidos', 7.0: ' Otro', 8.0: ' NS', 9.0: ' NC'}, 'P7_1': {1.0: ' Acuerdo', 2.0: ' Desacuerdo', 3.0: ' Acuerdo en parte', 4.0: ' Desacuerdo en parte', 8.0: ' NS', 9.0: ' NC'}, 'P7_2': {1.0: ' Acuerdo', 2.0: ' Desacuerdo', 3.0: ' Acuerdo en parte', 4.0: ' Desacuerdo en parte', 8.0: ' NS', 9.0: ' NC'}, 'P7_3': {1.0: ' Acuerdo', 2.0: ' Desacuerdo', 3.0: ' Acuerdo en parte', 4.0: ' Desacuerdo en parte', 8.0: ' NS', 9.0: ' NC'}, 'P8_1': {1.0: 'A', 2.0: 'B', 3.0: 'Ambos', 8.0: 'NS', 9.0: 'NC', 11.0: 'Enseñanza'}, 'P8_2': {1.0: 'A', 2.0: 'B', 3.0: 'Ambos', 8.0: 'NS', 9.0: 'NC', 11.0: 'Enseñanza'}, 'P8_3': {1.0: 'A', 2.0: 'B', 3.0: 'Ambos', 8.0: 'NS', 9.0: 'NC', 11.0: 'Enseñanza'}, 'P8_4': {1.0: 'A', 2.0: 'B', 3.0: 'Ambos', 8.0: 'NS', 9.0: 'NC', 11.0: 'Enseñanza'}, 'P9_1': {11.0: ' Preocupación', 12.0: ' Miedo', 13.0: ' Coraje', 14.0: ' Tristeza', 15.0: ' Fastidio', 16.0: ' Rencor', 17.0: ' Indignación', 18.0: ' Molestia', 19.0: ' Enojo, ira', 20.0: ' Temor', 21.0: ' Odio', 22.0: ' Armonia', 23.0: ' Esperanza', 24.0: ' Inseguridad', 25.0: ' Recentimiento', 26.0: ' Inconformidad, Insatisfacción', 27.0: ' Decepción', 28.0: ' Incertidumbre, Confunsión', 29.0: ' Desconfianza', 30.0: ' Angustia', 31.0: ' Tranquilidad', 32.0: ' Felicidad, Alegria', 33.0: ' impotencia', 34.0: ' Ansiedad, Desesperación', 35.0: ' Compromiso', 36.0: ' Dolor', 37.0: ' Amor', 38.0: ' Venganza', 39.0: ' Desprecio', 40.0: ' Egoismo', 41.0: ' Humildad', 42.0: ' Respeto', 43.0: ' Envidia', 44.0: ' Frustración', 45.0: ' Apatía', 46.0: ' Agresión', 47.0: ' Desagrado', 48.0: ' Abandono', 49.0: ' Nerviosismo', 96.0: ' Insuficientemente especificado', 98.0: ' NS', 99.0: ' NC'}, 'P9_1a_1': {1.0: 'Preocupación', 2.0: 'Miedo', 3.0: 'Desilusión', 4.0: 'Enojo', 5.0: 'Tristeza', 6.0: 'Confianza', 7.0: 'Esperanza', 8.0: 'Odio', 9.0: 'Deconfianza', 98.0: 'NS', 99.0: 'NC'}, 'P9_2': {11.0: ' Preocupación', 12.0: ' Miedo', 13.0: ' Coraje', 14.0: ' Tristeza', 15.0: ' Fastidio', 16.0: ' Rencor', 17.0: ' Indignación', 18.0: ' Molestia', 19.0: ' Enojo, ira', 20.0: ' Temor', 21.0: ' Odio', 22.0: ' Armonia', 23.0: ' Esperanza', 24.0: ' Inseguridad', 25.0: ' Recentimiento', 26.0: ' Inconformidad, Insatisfacción', 27.0: ' Decepción', 28.0: ' Incertidumbre, Confunsión', 29.0: ' Desconfianza', 30.0: ' Angustia', 31.0: ' Tranquilidad', 32.0: ' Felicidad, Alegria', 33.0: ' impotencia', 34.0: ' Ansiedad, Desesperación', 35.0: ' Compromiso', 36.0: ' Dolor', 37.0: ' Amor', 38.0: ' Venganza', 39.0: ' Desprecio', 40.0: ' Egoismo', 41.0: ' Humildad', 42.0: ' Respeto', 43.0: ' Envidia', 44.0: ' Frustración', 45.0: ' Apatía', 46.0: ' Agresión', 47.0: ' Desagrado', 48.0: ' Abandono', 49.0: ' Nerviosismo', 96.0: ' Insuficientemente especificado', 98.0: ' NS', 99.0: ' NC'}, 'P9_2a_1': {1.0: 'Preocupación', 2.0: 'Miedo', 3.0: 'Desilusión', 4.0: 'Enojo', 5.0: 'Tristeza', 6.0: 'Confianza', 7.0: 'Esperanza', 8.0: 'Odio', 9.0: 'Deconfianza', 98.0: 'NS', 99.0: 'NC'}, 'P9_3': {11.0: ' Preocupación', 12.0: ' Miedo', 13.0: ' Coraje', 14.0: ' Tristeza', 15.0: ' Fastidio', 16.0: ' Rencor', 17.0: ' Indignación', 18.0: ' Molestia', 19.0: ' Enojo, ira', 20.0: ' Temor', 21.0: ' Odio', 22.0: ' Armonia', 23.0: ' Esperanza', 24.0: '  ...

# %%
# Out:
# dict_keys(['column_names', 'column_labels', 'column_names_to_labels', 'file_encoding', 'number_columns', 'number_rows', 'variable_value_labels', 'value_labels', 'variable_to_label', 'notes', 'original_variable_types', 'readstat_variable_types', 'table_name', 'missing_ranges', 'missing_user_values', 'variable_storage_width', 'variable_display_width', 'variable_alignment', 'variable_measure', 'creation_time', 'modification_time', 'file_label', 'file_format'])

# %%
meta.column_names_to_labels
# Out:
# {'ID_BASE': None,
#  'EDO': 'Estado',
#  'MUNI': 'Municipio',
#  'LOC': 'Localidad',
#  'AGEB': 'Ageb',
#  'FOLIO': 'Folio',
#  'DIA_1': 'Dia',
#  'MES_1': 'Mes',
#  'HR_INI_1_1': 'Hora de Inicio',
#  'HR_FIN_1_1': 'Hora de Fin',
#  'DURA_1': 'Dura',
#  'RESUL_1': 'Resultado',
#  'DIA_2': 'Dia',
#  'MES_2': 'Mes',
#  'HR_INI_2_1': 'Hora de Inicio',
#  'HR_FIN_2_1': 'Hora de Fin',
#  'DURA_2': 'Dura',
#  'RESUL_2': 'Resultado',
#  'DIA_3': 'Dia',
#  'MES_3': 'Mes',
#  'HR_INI_3_1': 'Hora de Inicio',
#  'HR_FIN_3_1': 'Hora de Fin',
#  'DURA_3': 'Dura',
#  'RESUL_3': 'Resultado',
#  'DIA_4': 'Dia',
#  'MES_4': 'Mes',
#  'HR_INI_4_1': 'Hora de Inicio',
#  'HR_FIN_4_1': 'Hora de Fin',
#  'DURA_4': 'Dura',
#  'RESUL_4': 'Resultado',
#  'DIA_5': 'Dia',
#  'MES_5': 'Mes',
#  'DIA_6': 'Dia',
#  'MES_6': 'Mes',
#  'DIA_7': 'Dia',
#  'MES_7': 'Mes',
#  'P1': 'P1. Comparada con la situación que tenía el país hace un año, ¿cómo diría usted que es la situación actual del país: mejor o peor?',
#  'P2': 'P2. De las siguientes palabras, ¿con cuál está usted más de acuerdo para describir la situación política del país?',
#  'P3': 'P3. En general, ¿cree usted que en el próximo año la situación del país...?',
#  'P4': 'P4. ¿Qué tanto se interesa usted en los asuntos públicos?',
#  'P5': 'P5. ¿Con qué frecuencia acostumbra leer, ver o escuchar noticias o programas sobre política o asuntos públicos?',
#  'P6': 'P6. ¿Cuál es el medio de comunicación que más utiliza para informarse de los asuntos públicos?',
#  'P7_1': 'P7_1. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? La obediencia y el respeto a la autoridad son los valores más importantes que un niño debe aprender',
#  'P7_2': 'P7_2. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? Las leyes tienen que cumplirse estrictamente si queremos conservar nuestra forma de vida',
#  'P7_3': 'P7_3. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? La mayoría de los problemas sociales se resolverían si pudiéramos deshacernos de las personas inmorales',
#  'P8_1': 'P8_1. Le voy a leer algunas cualidades, A) independencia o B) respeto a sus mayores',
#  'P8_2': 'P8_2. Le voy a leer algunas cualidades, A) Obediencia o B) confianza en sí mismos',
#  'P8_3': 'P8_3. Le voy a leer algunas cualidades, A) Curiosidad o B) Buenos modales',
#  'P8_4': 'P8_4. Le voy a leer algunas cualidades, A) Pensar en los derechos y los sentimientos de los demás, o B) que tengan buena conducta',
#  'P9_1': 'P9_1. ¿Cuál cree que es el sentimiento que más predomina entre la gente en estos días? 1 Mención',
#  'P9_1a_1': 'P9_1. ¿Cuál cree que es el sentimiento que más predomina entre la gente en estos días? 1 Mención',
#  'P9_2': 'P9_2. ¿Cuál cree que es el sentimiento que más predomina entre la gente en estos días? 2 Mención',
#  'P9_2a_1': 'P9_2. ¿Cuál cree que es el sentimiento que más predomina entre la gente en estos días? 2 Mención',
#  'P9_3': 'P9_3. ¿Cuál cree que es el sentimiento que más predomina entre la gente en estos días? 3 Mención',
#  'P9_3a_1': 'P9_3. ¿Cuál cree que es el sentimiento que más predomina entre la gente en estos días? 3 Mención',
#  'P10': 'P10. Por lo que usted piensa, ¿qué es lo que más divide al país?',
#  'P10a_1': 'P10. Por lo que usted piensa, ¿qué es lo que más divide al país?',
#  'P11': 'P11. Y en su opinión, ¿qué es lo que mantiene más unido al país?',
#  'P11a_1': 'P11. Y en su opinión, ¿qué es lo que mantiene más unido al país?',
#  'P12_1': 'P12_1. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? La mayoría de la gente es honrada y se puede confiar en ella',
#  'P12_2': 'P12_2. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? La gente se interesa solo en su propio bienestar',
#  'P12_3': 'P12_3. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? Si uno tiene un problema siempre hay alguien que le da la mano',
#  'P12_4': 'P12_4. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? Hay que tener cuidado porque todos se quieren aprovechar de uno',
#  'P12_5': 'P12_5. ¿Qué tan de acuerdo o en desacuerdo está usted con las siguientes frases? Se siente aceptado(a) como un miembro de esta comunidad',
#  'P13_1': 'P13_1. En una escala de 0 a 10,¿qué tanta confianza tiene usted en la policía?',
#  'P13_2': 'P13_2. En una escala de 0 a 10,¿qué tanta confianza tiene usted en la familia?',
#  'P13_3': 'P13_3. En una escala de 0 a 10,¿qué tanta confianza tiene usted en los maestros?',
#  'P13_4': 'P13_4. En una escala de 0 a 10,¿qué tanta confianza tiene usted en los medios de comunicación?',
#  'P13_5': 'P13_5. En una escala de 0 a 10,¿qué tanta confianza tiene usted en el Presidente de la República?',
#  'P13_6': 'P13_6. En una escala de 0 a 10,¿qué tanta confianza tiene usted en la Iglesia?',
#  'P13_7': 'P13_7. En una escala de 0 a 10,¿qué tanta confianza tiene usted en los jueces y magistrados?',
#  'P13_8': 'P13_8. En una escala de 0 a 10,¿qué tanta confianza tiene usted en las organizaciones no gubernamentales?',
#  'P13_9': 'P13_9. En una escala de 0 a 10,¿qué tanta confianza tiene usted en los diputados federales?',
#  'P13_10': 'P13_10. En una escala de 0 a 10,¿qué tanta confianza tiene usted en la Suprema Corte de Justicia de la Nación?',
#  'P13_11': 'P13_11. En una escala de 0 a 10,¿qué tanta confianza tiene usted en los sindicatos?',
#  'P13_12': 'P13_12. En una escala de 0 a 10,¿qué tanta confianza tiene usted en el Instituto Nacional Electoral (antes IFE)?',
#  'P13_13': 'P13_13. En una escala de 0 a 10,¿qué tanta confianza tiene usted en los partidos políticos?',
#  'P13_14': 'P13_14. En una escala de 0 a 10,¿qué tanta confianza tiene usted en la Comisión Nacional de los Derechos Humanos?',
#  'P13_15': 'P13_15. En una escala de 0 a 10,¿qué tanta confianza tiene usted en el Ministerio Público?',
#  'P13_16': 'P13-16. En una escala de 0 a 10,¿qué tanta confianza tiene usted en las universidades públicas?',
#  'P13_17': 'P13_17. En una escala de 0 a 10,¿qué tanta confianza tiene usted en los tribunales de justicia?',
#  'P13_18': 'P13_18. En una escala de 0 a 10,¿qué tanta confianza tiene usted en el Ejército?',
#  'P13_19': 'P13_19. En una escala de 0 a 10,¿qué tanta confianza tiene usted en el INEGI?',
#  'P14': 'P14. Si un grupo de vecinos con el propósito de que se cumplan sus demandas bloquea una autopista, ¿qué debería hacer el gobierno: cumplir sus demandas o usar la fuerza pública para desbloquear la autopista?',
#  'P15': 'P15. Si la policía sabe que un detenido violó a una mujer, pero no tiene pruebas suficientes, ¿está usted de acuerdo o en desacuerdo en que sea torturado para obligarlo a confesar?',
#  'P16': 'P16. ¿Por qué respeta y obedece las leyes?',
#  'P17': 'P17. En una escala de 0 a 10, donde 0 es “no respeta nada” y 10 es “respeto mucho”, ¿qué tanto cree que las personas respetan la ley?',
#  'P18': 'P18. En la misma escala, ¿qué tanto respeta usted la ley?',
#  'P19': 'P19. ¿Qué tan de acuerdo o en desacuerdo está usted con la frase: violar la ley no es tan malo, lo malo es que te sorprendan?',
#  'P20': 'P20. ¿Sabe en qué año se aprobó la Constitución que actualmente nos rige?',
#  'P20A': 'P20a. ¿En qué año?',
#  'P21': 'P21. ¿La Constitución actual nació a partir de…?',
#  'P22': 'P22. Para usted, ¿cuál fue la aportación de la Constitución de 1917 para el mundo?',
#  'P22a_1': 'P22. Para usted, ¿cuál fue la aportación de la Constitución de 1917 para el mundo?',
#  'P23': 'P23. Por lo que usted piensa, ¿la Constitución que tenemos ahora es...?',
#  'P24': 'P24. En su opinión, ¿qué sería preferible: hacer una constitución nueva, cambiarla sólo en parte o dejarla como está?',
#  'P25': 'P25. Por lo que usted sabe, ¿con qué frecuencia se reforma la Constitución?',
#  'P26': 'P26. ¿Considera usted que está bien o está mal que la Constitución se reforme con frecuencia?',
#  'P27': 'P27. Las personas que no saben de leyes ¿deben o no deben opinar sobre los cambios a la Constitución?',
#  'P28': 'P28. Por lo que usted piensa, ¿los ciudadanos deben participar o no deben participar en la aprobación o rechazo de las reformas a la Constitución?',
#  'P28A': 'P28a. ¿Cómo deben participar? (ENCUESTADOR: Acepte la primera respuesta sin abreviar)',
#  'P28Aa_1': 'P28a. ¿Cómo deben participar? (ENCUESTADOR: Acepte la primera respuesta sin abreviar)',
#  'P29': 'P29. ¿Qué tanto considera usted que conoce la constitución: ¿mucho, poco o nada?',
#  'P30': 'P30. ¿Qué tanto cree que se cumple la Constitución en México?',
#  'P31': 'P31. En general, ¿qué tanto considera usted que se habla de la Constitución: mucho o poco?',
#  'P32': 'P32. ¿Quién le habló a usted de la Constitución por primera vez?',
#  'P33_1': 'P33. ¿En dónde escucha hablar más de la Constitución hoy? 1 Mencion',
#  'P33_2': 'P33. ¿En dónde escucha hablar más de la Constitución hoy? 2 Mención',
#  'P33_3': 'P33. ¿En dónde escucha hablar más de la Constitución hoy? 3 Mención',
#  'P34': 'P34. Por lo que usted piensa, ¿se debería o no se debería convocar a un congreso constituyente (para hacer una nueva constitución)?',
#  'P35_1': 'P35_1. Por lo que usted ha visto, ¿en qué medida en nuestro país se puede poner el negocio que se quiera?',
#  'P35_2': 'P35_2. Por lo que usted ha visto, ¿en qué medida en nuestro país se puede expresar lo que se piensa?',
#  'P35_3': 'P35_3. Por lo que usted ha visto, ¿en qué medida en nuestro país se puede votar por el partido que se quiera?',
#  'P35_4': 'P35_4. Por lo que usted ha visto, ¿en qué medida en nuestro país se puede tener la religión que se desea?',
#  'P35_5': 'P35_5. Por lo que usted ha visto, ¿en qué medida en nuestro país se puede estudiar lo que se quiera?',
#  'P35_6': 'P35_6. Por lo que usted ha visto, ¿en qué medida en nuestro país se puede trabajar en lo que se quiera?',
#  'P35_7': 'P35_7. Por lo que usted ha visto, ¿en qué medida en nuestro país se puede reunirse con quien uno desee?',
#  'P36': 'P36. En la Constitución no solo hay derechos, sino también obligaciones. ¿Podría decirme usted alguna obligación que esté en la Constitución?',
#  'P36a_1': 'P36. En la Constitución no solo hay derechos, sino también obligaciones. ¿Podría decirme usted alguna obligación que esté en la Constitución?',
#  'P37_1': 'P37_1. ¿Qué es más importante para usted?',
#  'P37_2': 'P37_2. ¿Qué es más importante para usted? ¿Y en segundo lugar?',
#  'P38': 'P38. ¿Qué tanto confía usted en el gobierno?',
#  'P39_1': 'P39_1. ¿Y por qué confía en el gobierno? 1 Mención',
#  'P39_1a_1': 'P39_1. ¿Y por qué confía en el gobierno? 1 Mención',
#  'P39_2': 'P39_2. ¿Y por qué confía en el gobierno? 2 Mención',
#  'P39_2a_1': 'P39_2. ¿Y por qué confía en el gobierno? 2 Mención',
#  'P39_3': 'P39_3. ¿Y por qué confía en el gobierno? 3 Mención',
#  'P39_3a_1': 'P39_3. ¿Y por qué confía en el gobierno? 3 Mención',
#  'P40_1': 'P40_1. ¿Y por qué no confía en el gobierno? 1 Mención',
#  'P40_1a_1': 'P40_1. ¿Y por qué no confía en el gobierno? 1 Mención',
#  'P40_2': 'P40_2. ¿Y por qué no confía en el gobierno? 2 Mención',
#  'P40_2a_1': 'P40_2. ¿Y por qué no confía en el gobierno? 2 Mención',
#  'P40_3': 'P40_3. ¿Y por qué no confía en el gobierno? 3 Mención',
#  'P40_3a_1': 'P40_3. ¿Y por qué no confía en el gobierno? 3 Mención',
#  'P41': 'P41. Y ahora le voy a pedir que me diga, ¿usted que tanto confía en los políticos?',
#  'P42': 'P42. ¿Por qué confía en los políticos?',
#  'P42a_1': 'P42. ¿Por qué confía en los políticos?',
#  'P43': 'P43. ¿Y por qué no confía en los políticos?',
#  'P43a_1': 'P43. ¿Y por qué no confía en los políticos?',
#  'P44': 'P44. Ahora le voy a pedir que hablemos sobre sus sentimientos con respecto al país. ¿Siente que el país va por el camino (rumbo) correcto, o siente que el país va por el camino equivocado?',
#  'P45_1': 'P45_1. Por lo que usted piensa, ¿en qué debería gastar más el gobierno? 1 Mención',
#  'P45_1a_1': 'P45_1. Por lo que usted piensa, ¿en qué debería gastar más el gobierno? 1 Mención',
#  'P45_2': 'P45_2. Por lo que usted piensa, ¿en qué debería gastar más el gobierno? 2 Mención',
#  'P45_2a_1': 'P45_2. Por lo que usted piensa, ¿en qué debería gastar más el gobierno? 2 Mención',
#  'P45_3': 'P45_3. Por lo que usted piensa, ¿en qué debería gastar más el gobierno? 3 Mención',
#  'P45_3a_1': 'P45_3. Por lo que usted piensa, ¿en qué debería gastar más el gobierno? 3 Mención',
#  'P46_1': 'P46_1. Y por lo que usted ha visto, ¿en qué gasta más el gobierno? 1 Mencion',
#  'P46_1a_1': 'P46_1. Y por lo que usted ha visto, ¿en qué gasta más el gobierno? 1 Mencion',
#  'P46_2': 'P46_2. Y por lo que usted ha visto, ¿en qué gasta más el gobierno? 2 Mencion',
#  'P46_2a_1': 'P46_2. Y por lo que usted ha visto, ¿en qué gasta más el gobierno? 2 Mencion',
#  'P46_3': 'P46_3. Y por lo que usted ha visto, ¿en qué gasta más el gobierno? 3 Mencion',
#  'P46_3a_1': 'P46_3. Y por lo que usted ha visto, ¿en qué gasta más el gobierno? 3 Mencion',
#  'P47': 'P47. En su opinión, ¿el gobierno responde o no responde a las necesidades de la gente?',
#  'P48': 'P48. En una escala de calificación del 0 al 10 como en la escuela, en donde cero es nada y diez es mucho, ¿qué tanta democracia diría usted que hay en México?',
#  'P49': 'P49. Y utilizando esa misma escala, ¿qué tanto confía usted en la democracia?',
#  'P50': 'P50. En su opinión, es verdadera o falsa la siguiente frase: “Un líder fuerte puede hacer más por el país que todas las leyes”',
#  'P51': 'P51. ¿Si una decisión fue tomada por la mayoría de las personas...?',
#  'P52': 'P52. En su opinión, ¿Cuándo un grupo social exige sus derechos mediante paros, bloqueos y plantones, ¿qué debe hacer el gobierno?',
#  'P53_1': 'P53_1. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Acudir a votar',
#  'P53_2': 'P53_2. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Quejarse ante las autoridades',
#  'P53_3': 'P53_3. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Acudir a su diputado',
#  'P53_4': 'P53_4. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Hacer una marcha',
#  'P53_5': 'P53_5. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Hacer denuncias en los medios de comunicación',
#  'P53_6': 'P53_6. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Hacer bloqueos o plantones',
#  'P53_7': 'P53_7. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Recurrir a un conocido',
#  'P53_8': 'P53_8. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Denunciarlo en las redes sociales virtuales',
#  'P53_9': 'P53_9. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Dar mordida',
#  'P53_10': 'P53_10. ¿Cuál cree que es la mejor forma de actuar para que a usted lo tomen en cuenta las autoridades? Otra (NO LEER)',
#  'P54_1': 'P54_1. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Amas de casa',
#  'P54_2': 'P54_2. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Personas muy pobres',
#  'P54_3': 'P54_3. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Estudiantes',
#  'P54_4': 'P54_4. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Campesinos',
#  'P54_5': 'P54_5. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Maestros',
#  'P54_6': 'P54_6. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Empresarios',
#  'P54_7': 'P54_7. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Indígenas',
#  'P54_8': 'P54_8. En caso de una protesta pública, las autoridades deberían o no deberían hacer excepciones en la aplicación de la ley, si los que protestan son: Mujeres',
#  'P55_1_1': 'P55_1_1. ¿Quién o quiénes realizan las siguientes funciones? Juzgar a los delincuentes 1 Mención',
#  'P55_1_2': 'P55_1_2. ¿Quién o quiénes realizan las siguientes funciones? Juzgar a los delincuentes 2 Mención',
#  'P55_1_3': 'P55_1_3. ¿Quién o quiénes realizan las siguientes funciones? Juzgar a los delincuentes 3 Mención',
#  'P55_2_1': 'P55_2_1. ¿Quién o quiénes realizan las siguientes funciones?Organizar las elecciones 1 Mención',
#  'P55_2_2': 'P55_2_2. ¿Quién o quiénes realizan las siguientes funciones?Organizar las elecciones 2 Mención',
#  'P55_2_3': 'P55_2_3. ¿Quién o quiénes realizan las siguientes funciones?Organizar las elecciones 3 Mención',
#  'P55_3_1': 'P55_3_1. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los gastos del gobierno 1 Mención',
#  'P55_3_2': 'P55_3_2. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los gastos del gobierno 2 Mención',
#  'P55_3_3': 'P55_3_3. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los gastos del gobierno 3 Mención',
#  'P55_4_1': 'P55_4_1. ¿Quién o quiénes realizan las siguientes funciones?Proteger los derechos de las personas 1 Mención',
#  'P55_4_2': 'P55_4_2. ¿Quién o quiénes realizan las siguientes funciones?Proteger los derechos de las personas 2 Mención',
#  'P55_4_3': 'P55_4_3. ¿Quién o quiénes realizan las siguientes funciones?Proteger los derechos de las personas 3 Mención',
#  'P55_5_1': 'P55_5_1. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los impuestos 1 Mención',
#  'P55_5_2': 'P55_5_2. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los impuestos 2 Mención',
#  'P55_5_3': 'P55_5_3. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los impuestos 3 Mención',
#  'P55_6_1': 'P55_6_1. ¿Quién o quiénes realizan las siguientes funciones?Orientar la economía 1 Mención',
#  'P55_6_2': 'P55_6_2. ¿Quién o quiénes realizan las siguientes funciones?Orientar la economía 2 Mención',
#  'P55_6_3': 'P55_6_3. ¿Quién o quiénes realizan las siguientes funciones?Orientar la economía 3 Mención',
#  'P55_7_1': 'P55_7_1. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los tratados internacionales 1 Mención',
#  'P55_7_2': 'P55_7_1. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los tratados internacionales 2 Mención',
#  'P55_7_3': 'P55_7_1. ¿Quién o quiénes realizan las siguientes funciones?Aprobar los tratados internacionales 3 Mención',
#  'P56': 'P56. ¿Con cuál de las siguientes frases cree usted que la mayoría de la gente está más de acuerdo?',
#  'P57': 'P57. Y, para usted, ¿qué es preferible?',
#  'P58': 'P58. Para que se fortalezca la democracia en México, ¿qué es más importante?',
#  'P59': 'P59. ¿A quién estaría más dispuesto a elegir como líder...?',
#  'P60': 'P60. ¿Qué tan de acuerdo o en desacuerdo está usted con la siguiente frase?: ("un funcionario público puede aprovecharse de su puesto si hace cosas buenas")',
#  'P61': 'P61. En su opinión, ¿qué tan importante es que el estado (o la Ciudad de México) donde usted vive tenga su propia Constitución?',
#  'P62': 'P62. A usted, ¿le interesan o no los asuntos que se discuten en el Congreso (diputados y senadores)?',
#  'P63': 'P63. Y, ¿le interesan o no los asuntos que se discuten en la Suprema Corte de Justicia de la Nación (Suprema Corte)?',
#  'P64': 'P64. Los ministros de la Suprema Corte discuten y votan en público las sentencias que dictan, ¿usted qué tan de acuerdo o en desacuerdo está con eso?',
#  'P65': 'P65. Y ¿qué tan de acuerdo o en desacuerdo está usted con que esas sesiones públicas se transmitan por televisión?',
#  'P66': 'P66. Si cuando una persona es detenida, las autoridades violan sus derechos, ¿qué tan de acuerdo o en desacuerdo está usted con que la Suprema Corte de Justicia la deje en libertad?',
#  'P67': 'P67. ¿Qué se debería hacer: organizar una nueva elección entre los dos primeros lugares o declarar ganador al partido que obtuvo más votos?',
#  'P68': 'P68. ¿Qué tan de acuerdo o en desacuerdo está usted con que dos o más partidos políticos participen juntos en las elecciones?',
#  'P69': 'P69. ¿Qué tan de acuerdo o en desacuerdo está con que dos o más partidos políticos de ideas muy diferentes participen juntos en las elecciones?',
#  'P70': 'P70. De las siguientes frases que le voy a leer, ¿cuál cree usted que es la razón PRINCIPAL por la cual los partidos políticos participan juntos en una elección?',
#  'P71': 'P71. Si el partido político de su preferencia participara junto a otro partido de ideas muy diferentes en una elección, ¿usted votaría por su partido o no?',
#  'P72': 'P72. ¿Qué es mejor para usted: que incluya en su gabinete a miembros de otros partidos políticos o que gobierne sin integrar a miembros de otros partidos políticos?',
#  'P73': 'P73. Si el presidente de la república integrara en su gabinete a miembros de partidos políticos diferentes al suyo, ¿usted cree que el gobierno federal funcionaría mejor o peor que ahora?',
#  'P74': 'P74. Ahora que la Ciudad de México (antes Distrito Federal) tendrá una Constitución Política propia, ¿usted cree que las cosas en ese (este) lugar: van a mejorar o van a empeorar?',
#  'P75_1': '75_1. Usted está de acuerdo o en desacuerdo con Las candidaturas independientes son buenas para nuestra democracia',
#  'P75_2': '75_2. Usted está de acuerdo o en desacuerdo con Un candidato independiente puede gobernar mejor que un candidato de partido político',
#  'P75_3': '75_3. Usted está de acuerdo o en desacuerdo con Los candidatos independientes están financiados por los partidos políticos',
#  'P75_4': '75_4. Usted está de acuerdo o en desacuerdo con Un candidato independiente es más honesto que un candidato de partido político',
#  'P76': 'P76. ¿Sabe usted qué es el amparo?',
#  'P76A': 'P76a. ¿Qué es el amparo?',
#  'P77': 'P77. En su opinión, ¿qué tanto sirve el amparo para defender los derechos de las personas?',
#  'P78': 'P78. Para usted, ¿qué es la justicia?',
#  'P79': 'P79. ¿Usted cree que el pueblo...?',
#  'P80': 'P80. Por lo que usted piensa: si un hombre mata a alguien y las autoridades no hacen nada, los miembros de la comunidad, ¿tienen o no tienen el derecho de tomar en sus manos el castigo?',
#  'P81': 'P81. Todos los sistemas de justicia cometen errores. ¿Qué es peor para la sociedad...?',
#  'P82': 'P82. La Constitución obliga a las autoridades a cumplir con los tratados internacionales en materia de derechos humanos. En su opinión, ¿qué tanto cree que eso contribuye a mejorar el respeto a los derechos humanos en el país?',
#  'P83': 'P83. ¿En qué ocasiones se justifica pegarle a una mujer?',
#  'P84_1': 'P84_1. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Cuando el embarazo es resultado de una violación',
#  'P84_2': 'P84_2. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Cuando la vida de la mujer está en peligro',
#  'P84_3': 'P84_3. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Cuando está en riesgo la salud de la mujer',
#  'P84_4': 'P84_4. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Cuando el producto presenta malformaciones congénitas graves',
#  'P84_5': 'P84_5. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Por falta de recursos económicos de la mujer',
#  'P84_6': 'P84_6. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Cuando la mujer es menor de edad',
#  'P84_7': 'P84_7. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Cuando la mujer es madre soltera',
#  'P84_8': 'P84_8. ¿Está usted de acuerdo o en desacuerdo con que se castigue penalmente a una mujer que se practique un aborto Cuando falló un método anticonceptivo',
#  'P85': 'P85. Por lo que usted ha visto, ¿en la actualidad?',
#  'P86': 'P86. Por lo que usted sabe, ¿la Constitución Mexicana establece o no establece que las mujeres y los hombres tienen igualdad de derechos?',
#  'P87': 'P87. ¿Considera que las personas homosexuales deben o no deben tener los mismos derechos que las demás personas?',
#  'P88': 'P88. ¿Considera usted que se debe o no se debe incorporar en la Constitución el derecho de las personas a contraer matrimonio con otra persona de su mismo sexo en todo el país?',
#  'P89': 'P89. Y en el mismo sentido, ¿considera usted que se debe o no se debe incorporar en la Constitución el derecho de las parejas del mismo sexo a adoptar niños en todo el país?',
#  'P90': 'P90. Autoridades religiosas se han manifestado en contra del matrimonio entre personas del mismo sexo. ¿Usted está de acuerdo o en desacuerdo con que las autoridades religiosas opinen sobre estos temas?',
#  'P91_1': 'P91_1. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Su religión?',
#  'P91_2': 'P91_2. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Ser hombre/mujer?',
#  'P91_3': 'P91_3. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a No tener dinero?',
#  'P91_4': 'P91_4. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Provenir de otro lugar?',
#  'P91_5': 'P91_5. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Su apariencia física?',
#  'P91_6': 'P91_6. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Su edad?',
#  'P91_7': 'P91_7. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Su preferencia sexual?',
#  'P91_8': 'P91_8. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Sus costumbres o su cultura?',
#  'P91_9': 'P91_9. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a El color de su piel?',
#  'P91_10': 'P91_10. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Su acento al hablar?',
#  'P91_11': 'P91_11. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Por su educación?',
#  'P91_12': 'P91_12. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Por su forma de vestir?',
#  'P91_13': 'P91_13. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Tener alguna discapacidad?',
#  'P91_14': 'P91_14. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Trabajar en el servicio doméstico?',
#  'P91_15': 'P91_15. En lo personal, ¿alguna vez ha sentido que sus derechos no han sido respetados debido a Otro?',
#  'P92': 'P92. En su opinión, ¿las costumbres de los indígenas...?',
#  'P93': 'P93. ¿Usted está de acuerdo o en desacuerdo con la reforma educativa?',
#  'P94': 'P94. ¿Con qué partido político se identifica más usted?',
#  'P95': 'P95. ¿Se considera usted como muy… (PRIISTA/PANISTA/PERREDISTA) o algo… (PRIISTA/PANISTA/ PERREDISTA)?',
#  'S1': 'S1. Sexo:',
#  'S2': 'S2. ¿Cuántos años cumplidos tiene usted?',
#  'S3_1': 'S3_1. ¿Cuál es el último nivel que estudió o cursó en la escuela?',
#  'S3_2': 'S3_2. ¿Cuál es el último grado que estudió o cursó en la escuela?',
#  'S4': 'S4. ¿Actualmente usted…?',
#  'S5': 'S5. ¿La semana pasada usted?',
#  'S6': 'S6. ¿Cuál es el nombre del oficio, puesto o cargo que usted desempeñó en su trabajo principal la semana pasada?',
#  'S8': 'S8. ¿A qué se dedica la empresa, negocio o institución para la que usted trabajó o ayudó la semana pasada?',
#  'S9': 'S9. ¿En su trabajo de la semana pasada usted fue?',
#  'S10': 'S10. ¿Cada cuándo obtiene usted sus ingresos o le pagan?',
#  'S11': 'S11. ¿Cuánto ganó o en cuánto calcula sus ingresos al mes?',
#  'S12': 'S12. (Encuestador: Clasificar el ingreso mencionado en la pregunta anterior en los siguientes grupos de ingreso)',
#  'S13': 'S13. Ahora pensando en todo lo que ganan los que viven en su casa, es decir, en la cantidad de dinero que ganaron todos los miembros de su hogar el mes pasado ¿Cuál fue el ingreso total de su hogar durante el mes pasado?',
#  'S14': 'S14. Solo para verificar, sumando todo el dinero que ganaron los miembros de su hogar ¿En cuál de los siguientes grupos de ingreso se encuentra su hogar pensando en el ingreso total del mes pasado?',
#  'OBS': 'Observaciones',
#  'Pondi2': 'Factor de expansión post-estratificado',
#  'total2': None,
#  'sexo': 'Sexo',
#  'edad': 'Edad',
#  'escol': 'Escolaridad',
#  'region': 'Región',
#  'ing_ind': 'Ingreso individual',
#  'ing_fam': 'Ingreso familiar',
#  'partido_pol': 'Partido Político',
#  'est_civil': 'Estado civil',
#  'cond_act': 'Condición de actividad'}

# %%
meta.variable_value_labels
# Out:
# {'P1': {1.0: ' Mejor',
#   2.0: ' Peor',
#   3.0: ' Igual de bien',
#   4.0: ' Igual de mal',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P2': {1.0: ' Prometedora',
#   2.0: ' Preocupante',
#   3.0: ' Tranquila',
#   4.0: ' Peligrosa',
#   5.0: ' Con oportunidades',
#   6.0: ' Mejor que antes',
#   7.0: ' Más o menos',
#   8.0: ' Peor que antes',
#   9.0: ' Otra',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P3': {1.0: ' Va a mejorar',
#   2.0: ' Va a empeorar',
#   3.0: ' Va a seguir igual de bien',
#   4.0: ' Va a seguir igual de mal',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P4': {1.0: ' Mucho',
#   2.0: ' Algo',
#   3.0: ' Poco',
#   4.0: ' Nada',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P5': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Sólo en ocasiones muy especiales',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P6': {1.0: ' Televisión',
#   2.0: ' Radio',
#   3.0: ' Internet',
#   4.0: ' Periódicos',
#   5.0: ' Revistas',
#   6.0: ' Amigos y conocidos',
#   7.0: ' Otro',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P7_1': {1.0: ' Acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P7_2': {1.0: ' Acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P7_3': {1.0: ' Acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P8_1': {1.0: 'A',
#   2.0: 'B',
#   3.0: 'Ambos',
#   8.0: 'NS',
#   9.0: 'NC',
#   11.0: 'Enseñanza'},
#  'P8_2': {1.0: 'A',
#   2.0: 'B',
#   3.0: 'Ambos',
#   8.0: 'NS',
#   9.0: 'NC',
#   11.0: 'Enseñanza'},
#  'P8_3': {1.0: 'A',
#   2.0: 'B',
#   3.0: 'Ambos',
#   8.0: 'NS',
#   9.0: 'NC',
#   11.0: 'Enseñanza'},
#  'P8_4': {1.0: 'A',
#   2.0: 'B',
#   3.0: 'Ambos',
#   8.0: 'NS',
#   9.0: 'NC',
#   11.0: 'Enseñanza'},
#  'P9_1': {11.0: ' Preocupación',
#   12.0: ' Miedo',
#   13.0: ' Coraje',
#   14.0: ' Tristeza',
#   15.0: ' Fastidio',
#   16.0: ' Rencor',
#   17.0: ' Indignación',
#   18.0: ' Molestia',
#   19.0: ' Enojo, ira',
#   20.0: ' Temor',
#   21.0: ' Odio',
#   22.0: ' Armonia',
#   23.0: ' Esperanza',
#   24.0: ' Inseguridad',
#   25.0: ' Recentimiento',
#   26.0: ' Inconformidad, Insatisfacción',
#   27.0: ' Decepción',
#   28.0: ' Incertidumbre, Confunsión',
#   29.0: ' Desconfianza',
#   30.0: ' Angustia',
#   31.0: ' Tranquilidad',
#   32.0: ' Felicidad, Alegria',
#   33.0: ' impotencia',
#   34.0: ' Ansiedad, Desesperación',
#   35.0: ' Compromiso',
#   36.0: ' Dolor',
#   37.0: ' Amor',
#   38.0: ' Venganza',
#   39.0: ' Desprecio',
#   40.0: ' Egoismo',
#   41.0: ' Humildad',
#   42.0: ' Respeto',
#   43.0: ' Envidia',
#   44.0: ' Frustración',
#   45.0: ' Apatía',
#   46.0: ' Agresión',
#   47.0: ' Desagrado',
#   48.0: ' Abandono',
#   49.0: ' Nerviosismo',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P9_1a_1': {1.0: 'Preocupación',
#   2.0: 'Miedo',
#   3.0: 'Desilusión',
#   4.0: 'Enojo',
#   5.0: 'Tristeza',
#   6.0: 'Confianza',
#   7.0: 'Esperanza',
#   8.0: 'Odio',
#   9.0: 'Deconfianza',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P9_2': {11.0: ' Preocupación',
#   12.0: ' Miedo',
#   13.0: ' Coraje',
#   14.0: ' Tristeza',
#   15.0: ' Fastidio',
#   16.0: ' Rencor',
#   17.0: ' Indignación',
#   18.0: ' Molestia',
#   19.0: ' Enojo, ira',
#   20.0: ' Temor',
#   21.0: ' Odio',
#   22.0: ' Armonia',
#   23.0: ' Esperanza',
#   24.0: ' Inseguridad',
#   25.0: ' Recentimiento',
#   26.0: ' Inconformidad, Insatisfacción',
#   27.0: ' Decepción',
#   28.0: ' Incertidumbre, Confunsión',
#   29.0: ' Desconfianza',
#   30.0: ' Angustia',
#   31.0: ' Tranquilidad',
#   32.0: ' Felicidad, Alegria',
#   33.0: ' impotencia',
#   34.0: ' Ansiedad, Desesperación',
#   35.0: ' Compromiso',
#   36.0: ' Dolor',
#   37.0: ' Amor',
#   38.0: ' Venganza',
#   39.0: ' Desprecio',
#   40.0: ' Egoismo',
#   41.0: ' Humildad',
#   42.0: ' Respeto',
#   43.0: ' Envidia',
#   44.0: ' Frustración',
#   45.0: ' Apatía',
#   46.0: ' Agresión',
#   47.0: ' Desagrado',
#   48.0: ' Abandono',
#   49.0: ' Nerviosismo',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P9_2a_1': {1.0: 'Preocupación',
#   2.0: 'Miedo',
#   3.0: 'Desilusión',
#   4.0: 'Enojo',
#   5.0: 'Tristeza',
#   6.0: 'Confianza',
#   7.0: 'Esperanza',
#   8.0: 'Odio',
#   9.0: 'Deconfianza',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P9_3': {11.0: ' Preocupación',
#   12.0: ' Miedo',
#   13.0: ' Coraje',
#   14.0: ' Tristeza',
#   15.0: ' Fastidio',
#   16.0: ' Rencor',
#   17.0: ' Indignación',
#   18.0: ' Molestia',
#   19.0: ' Enojo, ira',
#   20.0: ' Temor',
#   21.0: ' Odio',
#   22.0: ' Armonia',
#   23.0: ' Esperanza',
#   24.0: ' Inseguridad',
#   25.0: ' Recentimiento',
#   26.0: ' Inconformidad, Insatisfacción',
#   27.0: ' Decepción',
#   28.0: ' Incertidumbre, Confunsión',
#   29.0: ' Desconfianza',
#   30.0: ' Angustia',
#   31.0: ' Tranquilidad',
#   32.0: ' Felicidad, Alegria',
#   33.0: ' impotencia',
#   34.0: ' Ansiedad, Desesperación',
#   35.0: ' Compromiso',
#   36.0: ' Dolor',
#   37.0: ' Amor',
#   38.0: ' Venganza',
#   39.0: ' Desprecio',
#   40.0: ' Egoismo',
#   41.0: ' Humildad',
#   42.0: ' Respeto',
#   43.0: ' Envidia',
#   44.0: ' Frustración',
#   45.0: ' Apatía',
#   46.0: ' Agresión',
#   47.0: ' Desagrado',
#   48.0: ' Abandono',
#   49.0: ' Nerviosismo',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P9_3a_1': {1.0: 'Preocupación',
#   2.0: 'Miedo',
#   3.0: 'Desilusión',
#   4.0: 'Enojo',
#   5.0: 'Tristeza',
#   6.0: 'Confianza',
#   7.0: 'Esperanza',
#   8.0: 'Odio',
#   9.0: 'Deconfianza',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P10': {11.0: ' El miedo',
#   12.0: ' El dinero, la economía',
#   13.0: ' El narcotrafico',
#   14.0: ' Los pleitos entre gobiernos, guerras politicas',
#   15.0: ' Los pleitos entre la sociedad, desacuerdos',
#   16.0: ' El mal gobierno',
#   17.0: ' La falta de empleo, Desempleo',
#   18.0: ' La delincuencia (robos, asaltos)',
#   19.0: ' La injusticia',
#   20.0: ' La inseguridad',
#   21.0: ' La corrupción',
#   22.0: ' La inconformidad',
#   23.0: ' Los partidos politicos',
#   24.0: ' La religión',
#   25.0: ' Los ideas políticas',
#   26.0: ' La desigualdad de género',
#   27.0: ' La falta de educación',
#   28.0: ' La rebeldía',
#   29.0: ' La migración',
#   30.0: ' La Selección de la sociedad',
#   31.0: ' El poder',
#   32.0: ' La demografía',
#   33.0: ' Los tratados internacionales',
#   34.0: ' La ignorancia',
#   35.0: ' La angustia del pueblo',
#   36.0: ' La cultura',
#   37.0: ' La falta de interés',
#   38.0: ' La impunidad',
#   39.0: ' La desconfianza',
#   40.0: ' El odio',
#   41.0: ' Las leyes',
#   42.0: ' La falta de libertad de expresión',
#   43.0: ' Los valores',
#   44.0: ' Los malas noticias en los medios de comunicación',
#   45.0: ' La envidia',
#   46.0: ' Progresar',
#   47.0: ' La delincuencia organizada, (secuestros, muertes, extorsiones)',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P10a_1': {1.0: 'La situación de inseguridad',
#   2.0: 'La desigualdad económica y problemas económicos',
#   3.0: 'Problemas políticos, mal gobierno e injusticia',
#   4.0: 'Emociones y actitudes negativas',
#   5.0: 'Desigualdad social y problemas sociales',
#   6.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P11': {11.0: ' El dialogo entre las personas',
#   12.0: ' Los seres humanos',
#   13.0: ' La gente buena',
#   14.0: ' La igualdad',
#   15.0: ' Politicas, bien elaboradas',
#   16.0: ' Las leyes',
#   17.0: ' La familia',
#   18.0: ' Las fiestas',
#   19.0: ' La religión',
#   20.0: ' La situación del país',
#   21.0: ' El cambio',
#   22.0: ' La patria',
#   23.0: ' La esperanza',
#   24.0: ' Los usos y costumbres',
#   25.0: ' La injusticia del pais',
#   26.0: ' Las ganas de salir adelante (Progresar)',
#   27.0: ' Las actividades deportivas',
#   28.0: ' La ciencia',
#   29.0: ' La economia',
#   30.0: ' El amor',
#   31.0: ' La solidaridad',
#   32.0: ' Las propuestas',
#   33.0: ' La educación',
#   35.0: ' El trabajo',
#   36.0: ' Los valores',
#   37.0: ' Las raices',
#   38.0: ' La Fe',
#   39.0: ' Labores altruistas',
#   41.0: ' El dolor',
#   42.0: ' La libre expresión',
#   43.0: ' La confianza',
#   44.0: ' La comunicación',
#   45.0: ' La democracia',
#   46.0: ' La violencia',
#   47.0: ' La naturaleza',
#   48.0: ' La humildad de la gente',
#   50.0: ' La justicia',
#   51.0: ' La sabiduria',
#   52.0: ' La voluntad',
#   53.0: ' La soledad',
#   54.0: ' La seguridad',
#   55.0: ' El respeto',
#   56.0: ' La rebeldia',
#   57.0: ' La paz',
#   58.0: ' La ignorancia',
#   60.0: ' Las expectativas',
#   61.0: ' El orgullo',
#   62.0: ' La delincuencia',
#   63.0: ' La necesidad',
#   64.0: ' La salud',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P11a_1': {1.0: 'Las actitudes, sentimientos y valores positivos',
#   2.0: 'La búsqueda de una mejor situación social para el país',
#   3.0: 'Polìticas buenas, buen gobierno y justicia',
#   4.0: 'La cultura mexicana, sus tradiciones y su patrimonio',
#   5.0: 'La búsqueda de una mejor situación económica',
#   6.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P12_1': {1.0: ' De acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P12_2': {1.0: ' De acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P12_3': {1.0: ' De acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P12_4': {1.0: ' De acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P12_5': {1.0: ' De acuerdo',
#   2.0: ' Desacuerdo',
#   3.0: ' Acuerdo en parte',
#   4.0: ' Desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P13_1': {98.0: ' NS', 99.0: ' NC'},
#  'P13_2': {98.0: ' NS', 99.0: ' NC'},
#  'P13_3': {98.0: ' NS', 99.0: ' NC'},
#  'P13_4': {98.0: ' NS', 99.0: ' NC'},
#  'P13_5': {98.0: ' NS', 99.0: ' NC'},
#  'P13_6': {98.0: ' NS', 99.0: ' NC'},
#  'P13_7': {98.0: ' NS', 99.0: ' NC'},
#  'P13_8': {98.0: ' NS', 99.0: ' NC'},
#  'P13_9': {98.0: ' NS', 99.0: ' NC'},
#  'P13_10': {98.0: ' NS', 99.0: ' NC'},
#  'P13_11': {98.0: ' NS', 99.0: ' NC'},
#  'P13_12': {98.0: ' NS', 99.0: ' NC'},
#  'P13_13': {98.0: ' NS', 99.0: ' NC'},
#  'P13_14': {98.0: ' NS', 99.0: ' NC'},
#  'P13_15': {98.0: ' NS', 99.0: ' NC'},
#  'P13_16': {98.0: ' NS', 99.0: ' NC'},
#  'P13_17': {98.0: ' NS', 99.0: ' NC'},
#  'P13_18': {98.0: ' NS', 99.0: ' NC'},
#  'P13_19': {98.0: ' NS', 99.0: ' NC'},
#  'P14': {1.0: ' Cumplir sus demandas',
#   2.0: ' Usar la fuerza pública para desbloquear la autopista',
#   3.0: ' Ambas',
#   4.0: ' Nada',
#   5.0: ' Depende',
#   6.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P15': {1.0: ' De acuerdo',
#   2.0: ' En desacuerdo',
#   3.0: ' De acuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P16': {1.0: ' Porque cumplir la ley nos beneficia a todos',
#   2.0: ' Para no ser criticado por los demás',
#   3.0: ' Porque es un deber moral',
#   4.0: ' Para evitar daños a mi familia y amistades',
#   5.0: ' Para evitar castigos',
#   6.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P17': {98.0: ' NS', 99.0: ' NC'},
#  'P18': {98.0: ' NS', 99.0: ' NC'},
#  'P19': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   6.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P20': {1.0: ' Sí', 2.0: ' No', 8.0: ' NS', 9.0: ' NC'},
#  'P20A': {1.0: ' Respuesta correcta (1917)',
#   2.0: ' Respuesta incorrecta (cualquier otra fecha)',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P21': {1.0: ' La Independencia de México',
#   2.0: ' La Guerra de Reforma',
#   3.0: ' La Revolución Mexicana',
#   4.0: ' El movimiento estudiantil de 1968',
#   5.0: ' Otro',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P22': {11.0: 'El libre voto',
#   12.0: 'El fin de la esclavitud',
#   13.0: 'Darse a conocer políticamente',
#   14.0: 'Las leyes',
#   15.0: 'El obedecer',
#   16.0: 'El derecho a votar y ser votado',
#   17.0: 'El reglamento para el pueblo',
#   18.0: 'Organización para todos, la lucha',
#   19.0: 'Deberes de todos',
#   20.0: 'Respetar los derechos a la libre expresión',
#   21.0: 'Comercio con otros países',
#   22.0: 'La aportación solo fue para México, no para el mundo',
#   23.0: 'El mundo no tuvo ninguna aportación',
#   24.0: 'La independencia',
#   25.0: 'La soberania de México',
#   26.0: 'Las garantías individuales',
#   27.0: 'Más ideales',
#   28.0: 'Un mejor mundo',
#   29.0: 'Un mejor país',
#   30.0: 'Las reformas',
#   32.0: 'Respeto a los derechos',
#   33.0: 'Derechos de los ciudadanos',
#   34.0: 'Valorar a las personas que trabajan la tierra',
#   35.0: 'La democracia',
#   36.0: 'Mejores personas',
#   37.0: 'Trabajos',
#   38.0: 'Turismo',
#   39.0: 'Que fueramos un pais libre y soberano',
#   40.0: 'La reforma para trabajadores',
#   41.0: 'Mejorar los derechos humanos',
#   42.0: 'Corregir algunos actos de la gente',
#   44.0: 'La paz',
#   45.0: 'Tranquilidad',
#   46.0: 'Que México es un país autonomo',
#   49.0: 'Libre expresión',
#   50.0: 'Igualdad',
#   52.0: 'La no reelección',
#   53.0: 'Libre de delincuencia',
#   54.0: 'Que los autos ya no paguen tenencia',
#   55.0: 'Derechos de los pueblos indigenas',
#   56.0: 'Tomar en cuenta a México como país',
#   57.0: 'Educación básica',
#   58.0: 'Reforzar el derecho a un trabajo digno',
#   59.0: 'La justicia',
#   60.0: 'El orden',
#   61.0: 'Prevenir a la sociedad',
#   62.0: 'Crear obligaciones y derechos',
#   63.0: 'Buenas ideas',
#   64.0: 'Relaciones internaciones',
#   65.0: 'Para revoluciones',
#   66.0: 'Proteger los derechos',
#   67.0: 'El capitalismo',
#   68.0: 'El respeto',
#   69.0: 'Conocer las leyes',
#   70.0: 'Los valores',
#   71.0: 'El gobernar',
#   96.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P22a_1': {1.0: 'Derechos políticos',
#   2.0: 'Derechos sociales de trabajadores y campesinos',
#   3.0: 'Garantías individuales',
#   4.0: 'Soberanía',
#   5.0: 'Leyes',
#   6.0: 'Valores',
#   7.0: 'Orden y respeto',
#   8.0: 'Igualdad',
#   9.0: 'Mención dispersa',
#   10.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P23': {1.0: ' Adecuada para las necesidades que tiene el país',
#   2.0: ' Ya no responde a las necesidades del país',
#   3.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P24': {1.0: ' Hacer una constitución nueva',
#   2.0: ' Cambiarla sólo en parte',
#   3.0: ' Dejarla como está',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P25': {1.0: ' Con mucha frecuencia',
#   2.0: ' Con alguna frecuencia',
#   3.0: ' Con poca frecuencia',
#   4.0: ' No se reforma',
#   5.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P26': {1.0: ' Muy bien',
#   2.0: ' Bien',
#   3.0: ' Mal',
#   4.0: ' Muy mal',
#   5.0: ' Ni bien, ni mal',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P27': {1.0: ' Sí deben',
#   2.0: ' No deben',
#   3.0: ' Sí deben, en parte',
#   4.0: ' No deben, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P28': {1.0: ' Sí deben participar',
#   2.0: ' No deben participar',
#   3.0: ' Sólo en reformas importantes',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P28A': {11.0: ' Dialogo del pueblo',
#   12.0: ' Votando',
#   13.0: ' Participando, opinando y protestando',
#   14.0: ' Compartiendo las necesidades que tienen',
#   15.0: ' Haciendo reformas para mejorarlas',
#   16.0: ' Informandose, estudiando',
#   17.0: ' Por consulta',
#   18.0: ' Respetando las opiniones',
#   19.0: ' Respetando la justicia',
#   20.0: ' Supervisando las reformas',
#   21.0: ' Estar atentos a las reformas',
#   22.0: ' Por medio de las redes sociales',
#   23.0: ' Haciendo encuestas para saber su opinion',
#   24.0: ' Con censos',
#   25.0: ' Realizando reformas referentes al campo',
#   26.0: ' Revisando que sean beneficas',
#   27.0: ' Observando que sean honestas las leyes',
#   28.0: ' Con su experiencia',
#   29.0: ' Vigilando',
#   30.0: ' Expresar lo que siente',
#   31.0: ' Capacitandose',
#   32.0: ' Con demandas',
#   33.0: ' Con comunicados',
#   34.0: ' Actuando con forme este',
#   35.0: ' Aprendiendo de leyes',
#   36.0: ' Con ideas',
#   37.0: ' Por juntas',
#   38.0: ' Proponiendo mejores leyes',
#   39.0: ' Platicando sobre sus propuestas',
#   40.0: ' Declarando sus peticiones',
#   41.0: ' A traves de delegados',
#   42.0: ' Apoyando a los que saben de las leyes',
#   43.0: ' Aprovechandolas',
#   44.0: ' Demandas',
#   45.0: ' Renovación de contratos',
#   46.0: ' Son nuestros derechos',
#   47.0: ' Tomarnos en cuenta',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P28Aa_1': {1.0: 'Recoger opiniones, discutir, dialogar con los ciudadanos',
#   2.0: 'Consultas',
#   3.0: 'Encuestas y censos',
#   4.0: 'Votando (referendúm, plebicito)',
#   5.0: 'Propuestas de inciativa y modificación',
#   6.0: 'Informandose y estudiando',
#   7.0: 'Contralorías',
#   8.0: 'Demandas judiciales',
#   9.0: 'Otros medios',
#   10.0: 'Insuficientemente especificado',
#   11.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P29': {1.0: ' Mucho',
#   2.0: ' Poco',
#   3.0: ' Nada',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P30': {1.0: ' Mucho',
#   2.0: ' Poco',
#   3.0: ' Nada',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   6.0: ' Otro',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P31': {1.0: ' Mucho',
#   2.0: ' Poco',
#   3.0: ' Nada',
#   4.0: ' Otro',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P32': {1.0: ' En la escuela',
#   2.0: ' Casa',
#   3.0: ' Nadie',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC',
#   11.0: ' Medios de comunicación'},
#  'P33_1': {1.0: ' Casa',
#   2.0: ' Escuela',
#   3.0: ' Trabajo',
#   4.0: ' Iglesia o el templo',
#   5.0: ' Medios',
#   6.0: ' Ninguno',
#   7.0: ' Otros',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P33_2': {1.0: 'Casa',
#   2.0: 'Escuela',
#   3.0: 'Trabajo',
#   4.0: 'Iglesia o el templo',
#   5.0: 'Medios',
#   6.0: 'Ninguno',
#   7.0: 'Otros',
#   8.0: 'NS',
#   9.0: 'NC'},
#  'P33_3': {1.0: ' Casa',
#   2.0: ' Escuela',
#   3.0: ' Trabajo',
#   4.0: ' Iglesia o el templo',
#   5.0: ' Medios',
#   6.0: ' Ninguno',
#   7.0: ' Otros',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P34': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   4.0: ' No, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P35_1': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P35_2': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P35_3': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P35_4': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P35_5': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P35_6': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P35_7': {1.0: ' Siempre',
#   2.0: ' Nunca',
#   3.0: ' A veces',
#   4.0: ' Otra',
#   5.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P36': {11.0: ' Pagar impuestos',
#   12.0: ' Respetar las leyes',
#   13.0: ' Votar',
#   14.0: ' Cursar el minimo de estudios (Nivel básico)',
#   15.0: ' Ser buen ciudadano',
#   16.0: ' Servicio militar',
#   17.0: ' Respertar los simbolos patrios',
#   18.0: ' Respetar los derechos de los demás',
#   19.0: ' Brindar servicios publicos',
#   20.0: ' Respetar la vida',
#   21.0: ' Brindar servicio social a la comunidad',
#   22.0: ' Que tengan un trabajo digno',
#   23.0: ' Manutencion familiar, Cuidado de la familia',
#   24.0: ' Ser buen vecino',
#   25.0: ' Llevar los niños a la escuela',
#   26.0: ' Iguadad',
#   27.0: ' Trámites',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P36a_1': {1.0: 'Ser un buen ciudadano',
#   2.0: 'Votar',
#   3.0: 'Educarse, educar a los hijos',
#   4.0: 'Pagar impuestos',
#   5.0: 'Respetar la ley',
#   6.0: 'Servicio militar',
#   7.0: 'Servicio social',
#   8.0: 'Ofrecer un trabajo digno',
#   9.0: 'Manutención familiar',
#   10.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P37_1': {1.0: 'Una sociedad donde se apliquen y respeten las leyes',
#   2.0: 'Una sociedad sin delincuencia',
#   3.0: 'Una sociedad más democrática',
#   4.0: 'Una sociedad donde haya menos diferencias entre ricos y pobres',
#   5.0: 'Otro',
#   8.0: 'NS',
#   9.0: 'NC'},
#  'P37_2': {1.0: 'Una sociedad donde se apliquen y respeten las leyes',
#   2.0: 'Una sociedad sin delincuencia',
#   3.0: 'Una sociedad más democrática',
#   4.0: 'Una sociedad donde haya menos diferencias entre ricos y pobres',
#   5.0: 'Otro',
#   8.0: 'NS',
#   9.0: 'NC'},
#  'P38': {1.0: ' Mucho',
#   2.0: ' Algo',
#   3.0: ' Poco',
#   4.0: ' Nada',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P39_1': {11.0: ' No todos son corruptos',
#   12.0: ' No cumplen',
#   13.0: ' Cumplen con lo prometido',
#   14.0: ' Es la unica opcion',
#   15.0: ' Beneficios para ellos',
#   16.0: ' Corruptos',
#   17.0: ' Delincuencia',
#   18.0: ' Es su trabajo',
#   19.0: ' Ha perdido credibilidad',
#   20.0: ' Porque aun existen personas que quieren ayudar',
#   21.0: ' Esperanza',
#   22.0: ' Tienen los medios para mejorar',
#   23.0: ' Son nuestros gobernantes',
#   24.0: ' Son nuestros lideres, Maxima autoridad',
#   25.0: ' Son rotados',
#   26.0: ' Piensan en la gente',
#   27.0: ' Hacen buenas leyes',
#   28.0: ' Son honestps',
#   29.0: ' Libertad de expresion',
#   30.0: ' Para que cambien las leyes',
#   31.0: ' Seguridad',
#   32.0: ' Obras públicas',
#   33.0: ' No han hecho nada malo, correcto',
#   34.0: ' Es la ly',
#   35.0: ' No todo es malo, experiencia',
#   36.0: ' Egoismo',
#   37.0: ' Democratico, democracia',
#   38.0: ' Entrenados, capacitados',
#   39.0: ' Experiencia',
#   40.0: ' Algunas leyes respetan',
#   41.0: ' Forma de gobernar',
#   42.0: ' Son nuestras instituciones',
#   43.0: ' Por el bien comun',
#   44.0: ' Hacen lo mejor para el pais',
#   45.0: ' Economia',
#   46.0: ' Mienten',
#   47.0: ' Votaron por ellos',
#   48.0: ' Apoyaron la ayuda',
#   49.0: ' Mejoran la educacion',
#   50.0: ' Crean empleos',
#   51.0: ' Pobreza',
#   97.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P39_1a_1': {1.0: 'Cumplen con sus promesas',
#   2.0: 'Porque ayudan a mejorar las cosas',
#   3.0: 'Son nuestros gobernantes',
#   4.0: 'Hacen bien su trabajo',
#   5.0: 'Por la democracia',
#   7.0: 'Es la única opción',
#   8.0: 'Mención Dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P39_2': {11.0: ' No todos son corruptos',
#   12.0: ' No cumplen',
#   13.0: ' Cumplen con lo prometido',
#   14.0: ' Es la unica opcion',
#   15.0: ' Beneficios para ellos',
#   16.0: ' Corruptos',
#   17.0: ' Delincuencia',
#   18.0: ' Es su trabajo',
#   19.0: ' Ha perdido credibilidad',
#   20.0: ' Porque aun existen personas que quieren ayudar',
#   21.0: ' Esperanza',
#   22.0: ' Tienen los medios para mejorar',
#   23.0: ' Son nuestros gobernantes',
#   24.0: ' Son nuestros lideres, Maxima autoridad',
#   25.0: ' Son rotados',
#   26.0: ' Piensan en la gente',
#   27.0: ' Hacen buenas leyes',
#   28.0: ' Son honestps',
#   29.0: ' Libertad de expresion',
#   30.0: ' Para que cambien las leyes',
#   31.0: ' Seguridad',
#   32.0: ' Obras públicas',
#   33.0: ' No han hecho nada malo, correcto',
#   34.0: ' Es la ly',
#   35.0: ' No todo es malo, experiencia',
#   36.0: ' Egoismo',
#   37.0: ' Democratico, democracia',
#   38.0: ' Entrenados, capacitados',
#   39.0: ' Experiencia',
#   40.0: ' Algunas leyes respetan',
#   41.0: ' Forma de gobernar',
#   42.0: ' Son nuestras instituciones',
#   43.0: ' Por el bien comun',
#   44.0: ' Hacen lo mejor para el pais',
#   45.0: ' Economia',
#   46.0: ' Mienten',
#   47.0: ' Votaron por ellos',
#   48.0: ' Apoyaron la ayuda',
#   49.0: ' Mejoran la educacion',
#   50.0: ' Crean empleos',
#   51.0: ' Pobreza',
#   97.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P39_2a_1': {1.0: 'Cumplen con sus promesas',
#   2.0: 'Porque ayudan a mejorar las cosas',
#   3.0: 'Son nuestros gobernantes',
#   4.0: 'Hacen bien su trabajo',
#   5.0: 'Por la democracia',
#   7.0: 'Es la única opción',
#   8.0: 'Mención Dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P39_3': {11.0: ' No todos son corruptos',
#   12.0: ' No cumplen',
#   13.0: ' Cumplen con lo prometido',
#   14.0: ' Es la unica opcion',
#   15.0: ' Beneficios para ellos',
#   16.0: ' Corruptos',
#   17.0: ' Delincuencia',
#   18.0: ' Es su trabajo',
#   19.0: ' Ha perdido credibilidad',
#   20.0: ' Porque aun existen personas que quieren ayudar',
#   21.0: ' Esperanza',
#   22.0: ' Tienen los medios para mejorar',
#   23.0: ' Son nuestros gobernantes',
#   24.0: ' Son nuestros lideres, Maxima autoridad',
#   25.0: ' Son rotados',
#   26.0: ' Piensan en la gente',
#   27.0: ' Hacen buenas leyes',
#   28.0: ' Son honestps',
#   29.0: ' Libertad de expresion',
#   30.0: ' Para que cambien las leyes',
#   31.0: ' Seguridad',
#   32.0: ' Obras públicas',
#   33.0: ' No han hecho nada malo, correcto',
#   34.0: ' Es la ly',
#   35.0: ' No todo es malo, experiencia',
#   36.0: ' Egoismo',
#   37.0: ' Democratico, democracia',
#   38.0: ' Entrenados, capacitados',
#   39.0: ' Experiencia',
#   40.0: ' Algunas leyes respetan',
#   41.0: ' Forma de gobernar',
#   42.0: ' Son nuestras instituciones',
#   43.0: ' Por el bien comun',
#   44.0: ' Hacen lo mejor para el pais',
#   45.0: ' Economia',
#   46.0: ' Mienten',
#   47.0: ' Votaron por ellos',
#   48.0: ' Apoyaron la ayuda',
#   49.0: ' Mejoran la educacion',
#   50.0: ' Crean empleos',
#   51.0: ' Pobreza',
#   97.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P39_3a_1': {1.0: 'Cumplen con sus promesas',
#   2.0: 'Porque ayudan a mejorar las cosas',
#   3.0: 'Son nuestros gobernantes',
#   4.0: 'Hacen bien su trabajo',
#   5.0: 'Por la democracia',
#   7.0: 'Es la única opción',
#   8.0: 'Mención Dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P40_1': {11.0: ' No cumplen',
#   12.0: ' Rateros, Delincuentes',
#   13.0: ' Corruptos, Fraude',
#   14.0: ' Aprovechados',
#   15.0: ' Ignorantes',
#   16.0: ' Abuso de autoridad',
#   17.0: ' Asesinos',
#   18.0: ' Mentirosos, Desconfianza, Engañan',
#   19.0: ' Hipocritas',
#   20.0: ' No apoya los programas sociales',
#   21.0: ' No apoyan',
#   22.0: ' No hay razon para confiar',
#   23.0: ' No trabajan',
#   24.0: ' Leyes obsoletas',
#   25.0: ' No hay policias capacitados',
#   26.0: ' Gobernantes no preparados',
#   27.0: ' No hay soluciones',
#   28.0: ' Desempleo',
#   29.0: ' Desleales',
#   30.0: ' Incapaz',
#   31.0: ' Mal desempeño',
#   32.0: ' Nepotismo',
#   33.0: ' Entrenados, Capacitados',
#   34.0: ' Experiencia',
#   35.0: ' Solo nos acaban con impuestos',
#   36.0: ' No merecen el puesto',
#   37.0: ' No todos son corruptos',
#   39.0: ' Ayuda extranjera',
#   40.0: ' Inseguridad',
#   41.0: ' Deshonestos',
#   42.0: ' Egoismo',
#   43.0: ' El PRI',
#   44.0: ' Gastan en sindicatos',
#   45.0: ' Discriminan',
#   46.0: ' Injusticia',
#   47.0: ' Beneficio propio',
#   48.0: ' Pobreza',
#   49.0: ' Igualdad',
#   50.0: ' Disturbio',
#   51.0: ' Servicios de Salud',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P40_1a_1': {1.0: 'Por corruptos',
#   2.0: 'Porque roban',
#   3.0: 'No cumplen lo que prometen',
#   4.0: 'No apoyan el desarrollo social',
#   5.0: 'No tienen la preparación para sus puestos',
#   6.0: 'Sólo ven por sus beneficios',
#   7.0: 'No hacen su trabajo',
#   8.0: 'Mención dispersa',
#   9.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P40_2': {11.0: ' No cumplen',
#   12.0: ' Rateros, Delincuentes',
#   13.0: ' Corruptos, Fraude',
#   14.0: ' Aprovechados',
#   15.0: ' Ignorantes',
#   16.0: ' Abuso de autoridad',
#   17.0: ' Asesinos',
#   18.0: ' Mentirosos, Desconfianza, Engañan',
#   19.0: ' Hipocritas',
#   20.0: ' No apoya los programas sociales',
#   21.0: ' No apoyan',
#   22.0: ' No hay razon para confiar',
#   23.0: ' No trabajan',
#   24.0: ' Leyes obsoletas',
#   25.0: ' No hay policias capacitados',
#   26.0: ' Gobernantes no preparados',
#   27.0: ' No hay soluciones',
#   28.0: ' Desempleo',
#   29.0: ' Desleales',
#   30.0: ' Incapaz',
#   31.0: ' Mal desempeño',
#   32.0: ' Nepotismo',
#   33.0: ' Entrenados, Capacitados',
#   34.0: ' Experiencia',
#   35.0: ' Solo nos acaban con impuestos',
#   36.0: ' No merecen el puesto',
#   37.0: ' No todos son corruptos',
#   39.0: ' Ayuda extranjera',
#   40.0: ' Inseguridad',
#   41.0: ' Deshonestos',
#   42.0: ' Egoismo',
#   43.0: ' El PRI',
#   44.0: ' Gastan en sindicatos',
#   45.0: ' Discriminan',
#   46.0: ' Injusticia',
#   47.0: ' Beneficio propio',
#   48.0: ' Pobreza',
#   49.0: ' Igualdad',
#   50.0: ' Disturbio',
#   51.0: ' Servicios de Salud',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P40_2a_1': {1.0: 'Por corruptos',
#   2.0: 'Porque roban',
#   3.0: 'No cumplen lo que prometen',
#   4.0: 'No apoyan el desarrollo social',
#   5.0: 'No tienen la preparación para sus puestos',
#   6.0: 'Sólo ven por sus beneficios',
#   7.0: 'No hacen su trabajo',
#   8.0: 'Mención dispersa',
#   9.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P40_3': {11.0: ' No cumplen',
#   12.0: ' Rateros, Delincuentes',
#   13.0: ' Corruptos, Fraude',
#   14.0: ' Aprovechados',
#   15.0: ' Ignorantes',
#   16.0: ' Abuso de autoridad',
#   17.0: ' Asesinos',
#   18.0: ' Mentirosos, Desconfianza, Engañan',
#   19.0: ' Hipocritas',
#   20.0: ' No apoya los programas sociales',
#   21.0: ' No apoyan',
#   22.0: ' No hay razon para confiar',
#   23.0: ' No trabajan',
#   24.0: ' Leyes obsoletas',
#   25.0: ' No hay policias capacitados',
#   26.0: ' Gobernantes no preparados',
#   27.0: ' No hay soluciones',
#   28.0: ' Desempleo',
#   29.0: ' Desleales',
#   30.0: ' Incapaz',
#   31.0: ' Mal desempeño',
#   32.0: ' Nepotismo',
#   33.0: ' Entrenados, Capacitados',
#   34.0: ' Experiencia',
#   35.0: ' Solo nos acaban con impuestos',
#   36.0: ' No merecen el puesto',
#   37.0: ' No todos son corruptos',
#   39.0: ' Ayuda extranjera',
#   40.0: ' Inseguridad',
#   41.0: ' Deshonestos',
#   42.0: ' Egoismo',
#   43.0: ' El PRI',
#   44.0: ' Gastan en sindicatos',
#   45.0: ' Discriminan',
#   46.0: ' Injusticia',
#   47.0: ' Beneficio propio',
#   48.0: ' Pobreza',
#   49.0: ' Igualdad',
#   50.0: ' Disturbio',
#   51.0: ' Servicios de Salud',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P40_3a_1': {1.0: 'Por corruptos',
#   2.0: 'Porque roban',
#   3.0: 'No cumplen lo que prometen',
#   4.0: 'No apoyan el desarrollo social',
#   5.0: 'No tienen la preparación para sus puestos',
#   6.0: 'Sólo ven por sus beneficios',
#   7.0: 'No hacen su trabajo',
#   8.0: 'Mención dispersa',
#   9.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P41': {1.0: ' Mucho',
#   2.0: ' Algo',
#   3.0: ' Poco',
#   4.0: ' Nada',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P42': {11.0: ' Prometen cosas buenas',
#   12.0: ' Prosperidad',
#   13.0: ' No todos son malos',
#   14.0: ' Gobiernan',
#   15.0: ' Cumplen',
#   16.0: ' Honestidad',
#   17.0: ' Mentir',
#   18.0: ' Robar',
#   19.0: ' Propuestas',
#   20.0: ' Beneficios propios',
#   21.0: ' Respeto',
#   22.0: ' Apoyos',
#   23.0: ' Ayudan poco',
#   24.0: ' Situación politica del pais',
#   25.0: ' Mucha inseguridad',
#   26.0: ' Iniciativa',
#   27.0: ' Piensan en el pueblo',
#   28.0: ' Derechos',
#   29.0: ' Estudios',
#   30.0: ' Cumplir al pais',
#   31.0: ' Infraestructura',
#   32.0: ' Capacitados',
#   33.0: ' Incumplimiento',
#   34.0: ' No estan capacitados para el cargo',
#   35.0: ' Nepotismo',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P42a_1': {1.0: 'Por sus propuestas',
#   2.0: 'Por su capacidad',
#   3.0: 'Porque ayudan y mejoran las cosas',
#   4.0: 'Porque cumplen con su trabajo',
#   5.0: 'No todos son deshonestos',
#   6.0: 'Porque mienten',
#   7.0: 'Porque roban',
#   8.0: 'Solo ven por sus beneficios',
#   9.0: 'Por respeto',
#   10.0: 'Por su falta de capacidad',
#   11.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P43': {11.0: ' Se interesa por ellos',
#   12.0: ' Solo ellos ganan dinero',
#   13.0: ' Solo quieren dinero',
#   14.0: ' solo quieren robar',
#   15.0: ' Siempre dicen que hacen algo y no hacen nada',
#   16.0: ' Todos son iguales',
#   17.0: ' Delincuentes o rateros',
#   18.0: ' Corruptos',
#   19.0: ' No ayudan al pueblo',
#   20.0: ' Engaño',
#   21.0: ' Transparencia (Asuntos politicos)',
#   22.0: ' Impunidad',
#   23.0: ' Se preocupan por el pais',
#   24.0: ' No estan capacitados para el cargo',
#   25.0: ' Solo ven por los ricos',
#   26.0: ' Nepotismo',
#   27.0: ' Abuso de poder',
#   28.0: ' Falta de honestidad',
#   29.0: ' No respetan la ley',
#   30.0: ' Analfabetismo',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P43a_1': {1.0: 'Por corruptos',
#   2.0: 'Porque roban y abusan de su posición',
#   3.0: 'No cumplen lo que promeen',
#   4.0: 'No tienen preparación',
#   5.0: 'Solo ven por sus beneficios',
#   6.0: 'No hacen su trabajo',
#   7.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P44': {1.0: ' Va por el camino correcto',
#   2.0: ' Va por el camino equivocado',
#   3.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC',
#   11.0: ' Transformacion, proceso',
#   12.0: ' Va por el mismo camino',
#   13.0: ' Puede corregirse'},
#  'P45_1': {11.0: ' Educación',
#   12.0: ' Mas empleos',
#   13.0: ' Hospitales',
#   14.0: ' Mejores trabajos',
#   15.0: ' Escuelas',
#   16.0: ' En los pobres',
#   17.0: ' Delincuencia',
#   18.0: ' Casas',
#   19.0: ' Calles',
#   20.0: ' Carreteras o caminos',
#   21.0: ' Infraestructuras',
#   22.0: ' Economia',
#   23.0: ' Salud',
#   24.0: ' La gente (el pueblo)',
#   25.0: ' Seguridad',
#   26.0: ' Vigilancia',
#   27.0: ' Becas',
#   28.0: ' Servicios publicos',
#   29.0: ' Mejor salario',
#   30.0: ' Corrupcion',
#   31.0: ' Narcotrafico',
#   32.0: ' Programas sociales',
#   33.0: ' Ayuda a los ciudadanos',
#   34.0: ' Resago educativo',
#   35.0: ' Parques, areas recreativas',
#   36.0: ' Canasta basica y despensas',
#   37.0: ' Medicinas',
#   38.0: ' Pensiones',
#   39.0: ' Inseguridad',
#   40.0: ' Mejorar la ciudad',
#   41.0: ' Mejores policias',
#   42.0: ' Capacitacion docente',
#   43.0: ' Justicia',
#   44.0: ' Religion',
#   45.0: ' Mejora de la economia',
#   46.0: ' Obras publicas',
#   47.0: ' Proyectos resagados',
#   48.0: ' Mejorar la calidad de vida',
#   49.0: ' Empresas mexicanas',
#   50.0: ' Politica',
#   51.0: ' Actividades sociales',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P45_1a_1': {1.0: 'Educación',
#   2.0: 'Creación de empleos',
#   3.0: 'Salud',
#   4.0: 'Infraestructura',
#   5.0: 'Seguridad',
#   6.0: 'Viviendas',
#   7.0: 'Programas sociales',
#   8.0: 'En tener una mejor calidad de vida',
#   9.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P45_2': {11.0: ' Educación',
#   12.0: ' Mas empleos',
#   13.0: ' Hospitales',
#   14.0: ' Mejores trabajos',
#   15.0: ' Escuelas',
#   16.0: ' En los pobres',
#   17.0: ' Delincuencia',
#   18.0: ' Casas',
#   19.0: ' Calles',
#   20.0: ' Carreteras o caminos',
#   21.0: ' Infraestructuras',
#   22.0: ' Economia',
#   23.0: ' Salud',
#   24.0: ' La gente (el pueblo)',
#   25.0: ' Seguridad',
#   26.0: ' Vigilancia',
#   27.0: ' Becas',
#   28.0: ' Servicios publicos',
#   29.0: ' Mejor salario',
#   30.0: ' Corrupcion',
#   31.0: ' Narcotrafico',
#   32.0: ' Programas sociales',
#   33.0: ' Ayuda a los ciudadanos',
#   34.0: ' Resago educativo',
#   35.0: ' Parques, areas recreativas',
#   36.0: ' Canasta basica y despensas',
#   37.0: ' Medicinas',
#   38.0: ' Pensiones',
#   39.0: ' Inseguridad',
#   40.0: ' Mejorar la ciudad',
#   41.0: ' Mejores policias',
#   42.0: ' Capacitacion docente',
#   43.0: ' Justicia',
#   44.0: ' Religion',
#   45.0: ' Mejora de la economia',
#   46.0: ' Obras publicas',
#   47.0: ' Proyectos resagados',
#   48.0: ' Mejorar la calidad de vida',
#   49.0: ' Empresas mexicanas',
#   50.0: ' Politica',
#   51.0: ' Actividades sociales',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P45_2a_1': {1.0: 'Educación',
#   2.0: 'Creación de empleos',
#   3.0: 'Salud',
#   4.0: 'Infraestructura',
#   5.0: 'Seguridad',
#   6.0: 'Viviendas',
#   7.0: 'Programas sociales',
#   8.0: 'En tener una mejor calidad de vida',
#   9.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P45_3': {11.0: ' Educación',
#   12.0: ' Mas empleos',
#   13.0: ' Hospitales',
#   14.0: ' Mejores trabajos',
#   15.0: ' Escuelas',
#   16.0: ' En los pobres',
#   17.0: ' Delincuencia',
#   18.0: ' Casas',
#   19.0: ' Calles',
#   20.0: ' Carreteras o caminos',
#   21.0: ' Infraestructuras',
#   22.0: ' Economia',
#   23.0: ' Salud',
#   24.0: ' La gente (el pueblo)',
#   25.0: ' Seguridad',
#   26.0: ' Vigilancia',
#   27.0: ' Becas',
#   28.0: ' Servicios publicos',
#   29.0: ' Mejor salario',
#   30.0: ' Corrupcion',
#   31.0: ' Narcotrafico',
#   32.0: ' Programas sociales',
#   33.0: ' Ayuda a los ciudadanos',
#   34.0: ' Resago educativo',
#   35.0: ' Parques, areas recreativas',
#   36.0: ' Canasta basica y despensas',
#   37.0: ' Medicinas',
#   38.0: ' Pensiones',
#   39.0: ' Inseguridad',
#   40.0: ' Mejorar la ciudad',
#   41.0: ' Mejores policias',
#   42.0: ' Capacitacion docente',
#   43.0: ' Justicia',
#   44.0: ' Religion',
#   45.0: ' Mejora de la economia',
#   46.0: ' Obras publicas',
#   47.0: ' Proyectos resagados',
#   48.0: ' Mejorar la calidad de vida',
#   49.0: ' Empresas mexicanas',
#   50.0: ' Politica',
#   51.0: ' Actividades sociales',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P45_3a_1': {1.0: 'Educación',
#   2.0: 'Creación de empleos',
#   3.0: 'Salud',
#   4.0: 'Infraestructura',
#   5.0: 'Seguridad',
#   6.0: 'Viviendas',
#   7.0: 'Programas sociales',
#   8.0: 'En tener una mejor calidad de vida',
#   9.0: 'Mención dispersa',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P46_1': {11.0: ' Campañas politicas',
#   12.0: ' Despensas',
#   13.0: ' Politicos',
#   14.0: ' Carreteras',
#   15.0: ' Publicidad',
#   16.0: ' En ellos',
#   17.0: ' Se quedan todo el dinero',
#   18.0: ' En luces',
#   19.0: ' Construccion de casas que no sirven',
#   20.0: ' calles mal hechas',
#   21.0: ' Transporte',
#   22.0: ' Parques (Areas recreativas)',
#   23.0: ' Pavimentacion',
#   24.0: ' Autos nuevos (Lujos para politicos)',
#   25.0: ' Turismo (Viajes)',
#   26.0: ' Eventos deportivos, culturales y fiestas',
#   27.0: ' Corrupcion',
#   28.0: ' Comercio',
#   29.0: ' Autopistas',
#   30.0: ' Su sueldo',
#   31.0: ' Reformas',
#   32.0: ' En el pueblo',
#   33.0: ' Escuelas',
#   34.0: ' Carreteras',
#   35.0: ' Seguridad',
#   36.0: ' En su propio bienestar',
#   37.0: ' Brindar apoyo',
#   38.0: ' Empleos',
#   39.0: ' Hospitales',
#   40.0: ' Nepotismo',
#   41.0: ' Buena vida',
#   42.0: ' Becas',
#   43.0: ' Obras publicas',
#   44.0: ' Proceliptimos',
#   45.0: ' Educacion',
#   46.0: ' Casas',
#   47.0: ' Servicios publicos',
#   48.0: ' Presupuestos',
#   49.0: ' Deudas',
#   50.0: ' Trabajar bien',
#   51.0: ' Sindicatos',
#   52.0: ' Proyectos empresariales',
#   53.0: ' Salud',
#   54.0: ' Arreglar zonas turisticas',
#   55.0: ' Disturbios',
#   56.0: ' Pensiones',
#   57.0: ' Ayuda extranjera',
#   58.0: ' Relaciones internacionales',
#   59.0: ' Narcotrafico',
#   60.0: ' Fueros',
#   61.0: ' Adeudos fiscales',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P46_1a_1': {1.0: 'Proseltismo y procesos electorales',
#   2.0: 'Servicios y obras públicas',
#   3.0: 'Publicidad gubernamental',
#   4.0: 'Corrupción y beneficios para los gobernantes',
#   5.0: 'Servicios, obras y gastos innecesarios o inútiles',
#   6.0: 'Relaciones internacionales y fomento a la economía',
#   7.0: 'Funcionamiento de la administración pública',
#   8.0: 'Mención dispersa',
#   9.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P46_2': {11.0: ' Campañas politicas',
#   12.0: ' Despensas',
#   13.0: ' Politicos',
#   14.0: ' Carreteras',
#   15.0: ' Publicidad',
#   16.0: ' En ellos',
#   17.0: ' Se quedan todo el dinero',
#   18.0: ' En luces',
#   19.0: ' Construccion de casas que no sirven',
#   20.0: ' calles mal hechas',
#   21.0: ' Transporte',
#   22.0: ' Parques (Areas recreativas)',
#   23.0: ' Pavimentacion',
#   24.0: ' Autos nuevos (Lujos para politicos)',
#   25.0: ' Turismo (Viajes)',
#   26.0: ' Eventos deportivos, culturales y fiestas',
#   27.0: ' Corrupcion',
#   28.0: ' Comercio',
#   29.0: ' Autopistas',
#   30.0: ' Su sueldo',
#   31.0: ' Reformas',
#   32.0: ' En el pueblo',
#   33.0: ' Escuelas',
#   34.0: ' Carreteras',
#   35.0: ' Seguridad',
#   36.0: ' En su propio bienestar',
#   37.0: ' Brindar apoyo',
#   38.0: ' Empleos',
#   39.0: ' Hospitales',
#   40.0: ' Nepotismo',
#   41.0: ' Buena vida',
#   42.0: ' Becas',
#   43.0: ' Obras publicas',
#   44.0: ' Proceliptimos',
#   45.0: ' Educacion',
#   46.0: ' Casas',
#   47.0: ' Servicios publicos',
#   48.0: ' Presupuestos',
#   49.0: ' Deudas',
#   50.0: ' Trabajar bien',
#   51.0: ' Sindicatos',
#   52.0: ' Proyectos empresariales',
#   53.0: ' Salud',
#   54.0: ' Arreglar zonas turisticas',
#   55.0: ' Disturbios',
#   56.0: ' Pensiones',
#   57.0: ' Ayuda extranjera',
#   58.0: ' Relaciones internacionales',
#   59.0: ' Narcotrafico',
#   60.0: ' Fueros',
#   61.0: ' Adeudos fiscales',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P46_2a_1': {1.0: 'Proseltismo y procesos electorales',
#   2.0: 'Servicios y obras públicas',
#   3.0: 'Publicidad gubernamental',
#   4.0: 'Corrupción y beneficios para los gobernantes',
#   5.0: 'Servicios, obras y gastos innecesarios o inútiles',
#   6.0: 'Relaciones internacionales y fomento a la economía',
#   7.0: 'Funcionamiento de la administración pública',
#   8.0: 'Mención dispersa',
#   9.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P46_3': {11.0: ' Campañas politicas',
#   12.0: ' Despensas',
#   13.0: ' Politicos',
#   14.0: ' Carreteras',
#   15.0: ' Publicidad',
#   16.0: ' En ellos',
#   17.0: ' Se quedan todo el dinero',
#   18.0: ' En luces',
#   19.0: ' Construccion de casas que no sirven',
#   20.0: ' calles mal hechas',
#   21.0: ' Transporte',
#   22.0: ' Parques (Areas recreativas)',
#   23.0: ' Pavimentacion',
#   24.0: ' Autos nuevos (Lujos para politicos)',
#   25.0: ' Turismo (Viajes)',
#   26.0: ' Eventos deportivos, culturales y fiestas',
#   27.0: ' Corrupcion',
#   28.0: ' Comercio',
#   29.0: ' Autopistas',
#   30.0: ' Su sueldo',
#   31.0: ' Reformas',
#   32.0: ' En el pueblo',
#   33.0: ' Escuelas',
#   34.0: ' Carreteras',
#   35.0: ' Seguridad',
#   36.0: ' En su propio bienestar',
#   37.0: ' Brindar apoyo',
#   38.0: ' Empleos',
#   39.0: ' Hospitales',
#   40.0: ' Nepotismo',
#   41.0: ' Buena vida',
#   42.0: ' Becas',
#   43.0: ' Obras publicas',
#   44.0: ' Proceliptimos',
#   45.0: ' Educacion',
#   46.0: ' Casas',
#   47.0: ' Servicios publicos',
#   48.0: ' Presupuestos',
#   49.0: ' Deudas',
#   50.0: ' Trabajar bien',
#   51.0: ' Sindicatos',
#   52.0: ' Proyectos empresariales',
#   53.0: ' Salud',
#   54.0: ' Arreglar zonas turisticas',
#   55.0: ' Disturbios',
#   56.0: ' Pensiones',
#   57.0: ' Ayuda extranjera',
#   58.0: ' Relaciones internacionales',
#   59.0: ' Narcotrafico',
#   60.0: ' Fueros',
#   61.0: ' Adeudos fiscales',
#   96.0: ' Insuficientemente especificado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P46_3a_1': {1.0: 'Proseltismo y procesos electorales',
#   2.0: 'Servicios y obras públicas',
#   3.0: 'Publicidad gubernamental',
#   4.0: 'Corrupción y beneficios para los gobernantes',
#   5.0: 'Servicios, obras y gastos innecesarios o inútiles',
#   6.0: 'Relaciones internacionales y fomento a la economía',
#   7.0: 'Funcionamiento de la administración pública',
#   8.0: 'Mención dispersa',
#   9.0: 'Insuficientemente especificado',
#   98.0: 'NS',
#   99.0: 'NC'},
#  'P47': {1.0: ' Sí responde',
#   2.0: ' No responde',
#   3.0: ' Sí, en parte',
#   4.0: ' No, en parte',
#   5.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P48': {98.0: ' NS', 99.0: ' NC'},
#  'P49': {98.0: ' NS', 99.0: ' NC'},
#  'P50': {1.0: ' Verdadera',
#   2.0: ' Falsa',
#   3.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P51': {1.0: 'Usted la obedece aunque no le guste',
#   2.0: 'No la obedece si no le gusta',
#   3.0: 'Otra',
#   4.0: 'Ninguna',
#   8.0: 'NS',
#   9.0: 'NC'},
#  'P52': {1.0: 'Dialogar con el grupo',
#   2.0: 'Impedir que se realicen los paros y plantones',
#   3.0: 'Detener a los integrantes del movimiento',
#   4.0: 'Indemnizar y dar apoyos a los ciudadanos afectados',
#   5.0: 'Aceptar las demandas del grupo',
#   6.0: 'Nada',
#   7.0: 'Otra',
#   8.0: 'NS',
#   9.0: 'NC'},
#  'P53_1': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_2': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_3': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_4': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_5': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_6': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_7': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_8': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_9': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P53_10': {1.0: ' Sí', 2.0: ' No', 3.0: ' A veces', 8.0: ' NS', 9.0: ' NC'},
#  'P54_1': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P54_2': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P54_3': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P54_4': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P54_5': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P54_6': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P54_7': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P54_8': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' En parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_1_1': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_1_2': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_1_3': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_2_1': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_2_2': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_2_3': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_3_1': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_3_2': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_3_3': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_4_1': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_4_2': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_4_3': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_5_1': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_5_2': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_5_3': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_6_1': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_6_2': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_6_3': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_7_1': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_7_2': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P55_7_3': {1.0: ' CNDH',
#   2.0: ' INE',
#   3.0: ' Presidente',
#   4.0: ' Diputados',
#   5.0: ' Jueces',
#   6.0: ' Senadores',
#   7.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P56': {1.0: ' La democracia es preferible a cualquier otra forma de gobierno',
#   2.0: ' En algunas circunstancias, un gobierno no democrático puede ser mejor',
#   3.0: ' A la gente le da lo mismo',
#   4.0: ' Ninguna de las anteriores',
#   5.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P57': {1.0: ' La democracia es preferible a cualquier otra forma de gobierno',
#   2.0: ' En algunas circunstancias, un gobierno no democrático puede ser mejor',
#   3.0: ' Me da lo mismo',
#   4.0: ' Ninguna de las anteriores',
#   5.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P58': {1.0: ' Que el Presidente y los legisladores tengan una buena relación',
#   2.0: ' Que se respeten y apliquen las leyes',
#   3.0: ' Que los ciudadanos exijan cuentas al gobierno',
#   4.0: ' Que el gobierno sea honesto',
#   5.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P59': {1.0: ' Uno que respete las tradiciones de la comunidad',
#   2.0: ' Uno que conozca y aplique siempre las leyes',
#   3.0: ' Uno que convenza y tenga muchos seguidores',
#   4.0: ' Uno que tenga experiencia en el gobierno',
#   5.0: ' Uno que sea honesto y diga la verdad',
#   6.0: ' Ninguna de las anteriores',
#   7.0: ' Otro',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P60': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P61': {1.0: ' Muy importante',
#   2.0: ' Algo importante',
#   3.0: ' Poco importante',
#   4.0: ' Nada importante',
#   5.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P62': {1.0: ' Sí me interesan',
#   2.0: ' No me interesan',
#   3.0: ' Otra',
#   4.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P63': {1.0: ' Sí me interesan',
#   2.0: ' No me interesan',
#   3.0: ' Otra',
#   4.0: ' Depende',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P64': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P65': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P66': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P67': {1.0: ' Organizar una nueva elección entre los dos primeros lugares ó',
#   2.0: ' Declarar ganador al partido que obtuvo más votos',
#   3.0: ' Hacer recuento de votos',
#   4.0: ' Gobernar entre los dos candidatos',
#   5.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P68': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P69': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P70': {1.0: ' Para ganar más votos',
#   2.0: ' Para recibir más dinero',
#   3.0: ' Para mantener su registro',
#   4.0: ' Para derrotar a otro partido',
#   5.0: ' Otro',
#   8.0: ' NS',
#   9.0: ' NC',
#   11.0: ' Diversidad'},
#  'P71': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Depende',
#   4.0: ' No votaría',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P72': {1.0: ' Que incluya en su gabinete a miembros de otros partidos políticos',
#   2.0: ' Que gobierne sin integrar a miembros de otros partidos políticos',
#   3.0: ' Otro',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P73': {1.0: ' Mejor',
#   2.0: ' Peor',
#   3.0: ' Igual',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P74': {1.0: ' Van a mejorar',
#   2.0: ' Van a empeorar',
#   3.0: ' Van a seguir igual',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P75_1': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P75_2': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P75_3': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P75_4': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P76': {1.0: ' Sí', 2.0: ' No', 3.0: ' Más o menos', 8.0: ' NS', 9.0: ' NC'},
#  'P76A': {1.0: ' Forma de evitar ir a la cárcel',
#   2.0: ' Forma de protección y apoyo',
#   3.0: ' Otra ¿Cuál?',
#   8.0: ' NS',
#   9.0: ' NC',
#   11.0: ' Hacer valer los derechos',
#   12.0: ' Cometer un delito',
#   13.0: ' Interpretacion de la ley para corregir algo',
#   14.0: ' Ayuda en los separos'},
#  'P77': {1.0: ' Mucho',
#   2.0: ' Poco',
#   3.0: ' Nada(NO LEER)',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P78': {1.0: ' Cumplir la ley',
#   2.0: ' Forma de castigo',
#   3.0: ' Un medio para poner orden',
#   4.0: ' Respetar los derechos de las personas',
#   5.0: ' Es igualdad',
#   6.0: ' Es algo corrupto',
#   7.0: ' Otra',
#   8.0: ' Todas',
#   9.0: ' Ninguna',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P79': {1.0: 'Debe obedecer siempre las leyes',
#   2.0: 'Puede cambiar las leyes si no le parecen',
#   3.0: 'Puede desobedecer las leyes si le parecen injustas',
#   4.0: 'Otra',
#   8.0: 'NS',
#   9.0: 'NC'},
#  'P80': {1.0: ' Sí tienen el derecho',
#   2.0: ' No tienen del derecho',
#   3.0: ' Sí tienen el derecho, en parte',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P81': {1.0: ' Encarcelar a un inocente',
#   2.0: ' Dejar libre a un culpable',
#   3.0: ' Depende',
#   4.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P82': {1.0: ' Mucho',
#   2.0: ' Algo',
#   3.0: ' Poco',
#   4.0: ' Nada',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P83': {1.0: ' Cuando es necesario corregirla',
#   2.0: ' Cuando ella te pega',
#   3.0: ' Si te falta al respeto',
#   4.0: ' Nunca se justifica',
#   5.0: ' Depende',
#   6.0: ' Otra',
#   8.0: ' NS',
#   9.0: ' NC',
#   11.0: ' En defensa propia'},
#  'P84_1': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P84_2': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P84_3': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P84_4': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P84_5': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P84_6': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P84_7': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P84_8': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P85': {1.0: ' Las mujeres tienen más derechos que los hombres',
#   2.0: ' Las mujeres tienen los mismos derechos que los hombres',
#   3.0: ' Las mujeres tienen menos derechos que los hombres',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P86': {1.0: ' Sí lo establece',
#   2.0: ' No lo establece',
#   3.0: ' Sí lo establece, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P87': {1.0: ' Sí deben',
#   2.0: ' No deben',
#   3.0: ' Si deben, en parte',
#   4.0: ' No deben, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P88': {1.0: ' Sí se debe',
#   2.0: ' No se debe',
#   3.0: ' Sí debe, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P89': {1.0: ' Sí se debe',
#   2.0: ' No se debe',
#   3.0: ' Sí debe, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P90': {1.0: ' Muy de acuerdo',
#   2.0: ' De acuerdo',
#   3.0: ' En desacuerdo',
#   4.0: ' Muy en desacuerdo',
#   5.0: ' Ni de acuerdo, ni en desacuerdo',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_1': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_2': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_3': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_4': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_5': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_6': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_7': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_8': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_9': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_10': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_11': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_12': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_13': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_14': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P91_15': {1.0: ' Sí',
#   2.0: ' No',
#   3.0: ' Sí, en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P92': {1.0: ' Deben respetarse, aunque algunas estén en contra de los derechos individuales de las personas',
#   2.0: ' Sólo deben respetarse las que no estén en contra de los derechos individuales de las personas',
#   3.0: ' Otra',
#   4.0: ' Ninguna',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P93': {1.0: ' De acuerdo',
#   2.0: ' En desacuerdo',
#   3.0: ' De acuerdo en parte',
#   4.0: ' En desacuerdo en parte',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'P94': {1.0: ' PAN',
#   2.0: ' PRD',
#   3.0: ' PRI',
#   4.0: ' PT',
#   5.0: ' PVEM',
#   6.0: ' Convergencia',
#   7.0: ' Nueva Alianza (Panal)',
#   8.0: ' MORENA',
#   9.0: ' Partido Encuentro Social (PES)',
#   10.0: ' Otro',
#   11.0: ' Ninguno',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'P95': {1.0: ' Muy', 2.0: ' Algo', 3.0: ' Poco', 8.0: ' NS', 9.0: ' NC'},
#  'S1': {1.0: ' Hombre', 2.0: ' Mujer'},
#  'S2': {998.0: ' NS', 999.0: ' NC'},
#  'S3_1': {1.0: ' Ninguno',
#   2.0: ' Preescolar',
#   3.0: ' Primaria',
#   4.0: ' Secundaria',
#   5.0: ' Preparatoria o Bachillerato',
#   6.0: ' Normal',
#   7.0: ' Carrera técnica',
#   8.0: ' Licenciatura (Profesional)',
#   9.0: ' Maestría',
#   10.0: ' Doctorado',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'S4': {1.0: ' Vive con su pareja en unión libre',
#   2.0: ' Está separado(a)',
#   3.0: ' Está divorciado(a)',
#   4.0: ' Está viudo(a)',
#   5.0: ' Está casado(a)',
#   6.0: ' Está soltero(a)',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'S5': {1.0: ' Trabajó para obtener ingresos',
#   2.0: ' Trabajó sin pago ayudando en el negocio actividad que desempeña un familiar',
#   3.0: ' Trabajó sin pago ayudando en el negocio o actividad que desempeña una persona no familiar',
#   4.0: ' No trabajó, pero sí tiene trabajo',
#   5.0: ' Buscó trabajo',
#   6.0: ' Está en espera de que le resuelvan una solicitud de un trabajo al que acudió',
#   7.0: ' Es estudiante',
#   8.0: ' Se dedica a los quehaceres de su hogar',
#   9.0: ' Es jubilado(a) o pensionado(a)',
#   10.0: ' Está incapacitado(a) permanentemente para trabajar',
#   11.0: ' Otra situación¿Cuál?',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'S6': {1.0: ' Profesionistas y técnicos',
#   2.0: ' Funcionarios de los sectores público y privado',
#   3.0: ' Personal administrativo',
#   4.0: ' Comerciantes, vendedores y similares',
#   5.0: ' Trabajadores en servicios personales y conductores de vehículos',
#   6.0: ' Trabajadores en labores agropecuarias',
#   7.0: ' Trabajadores industriales',
#   8.0: ' Otro',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'S8': {1.0: ' Agropecuaria',
#   2.0: ' Industria',
#   3.0: ' Construcción',
#   4.0: ' Comercio',
#   5.0: ' Servicios',
#   6.0: ' Comunicaciones y transportes',
#   7.0: ' Administración pública y defensa',
#   8.0: ' Otra',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'S9': {1.0: ' Patrón',
#   2.0: ' Trabajador por su cuenta',
#   3.0: ' Trabajador a sueldo fijo, salario o jornal',
#   4.0: ' Trabajador a destajo',
#   5.0: ' Trabajador a comisión o porcentaje',
#   6.0: ' Trabajador sin pago',
#   7.0: ' Trabajador por honorarios',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'S10': {1.0: ' Diario',
#   2.0: ' Cada semana',
#   3.0: ' Cada 15 días',
#   4.0: ' Cada mes',
#   5.0: ' Cada año',
#   6.0: ' No recibe ingresos',
#   8.0: ' NS',
#   9.0: ' NC'},
#  'S11': {988888.0: ' NS', 999999.0: ' NC'},
#  'S12': {1.0: ' De 0 a 1 SM ($ 0 hasta $2,191 al mes)',
#   2.0: ' De 1 a 2 SM (De $2,192 hasta $4,382 al mes)',
#   3.0: ' De 2 a 3 SM (De $4,383 hasta $6,573 al mes)',
#   4.0: ' De 3 a 4 SM (De $6,574 hasta $8,765 al mes)',
#   5.0: ' De 4 a 5 SM (De $8,766 hasta $10,956 al mes)',
#   6.0: ' De 5 a 6 SM (De $10,957 hasta $13,147 al mes)',
#   7.0: ' De 6 a 7 SM (De $13,147 hasta $15,338 al mes)',
#   8.0: ' De 7 a 8 SM (De $15,339 hasta $17,529 al mes)',
#   9.0: ' De 8 a 9 SM (De $17,530 hasta $19,721al mes)',
#   10.0: ' De 9 a 10 SM (De $19,721 hasta $21,912 al mes)',
#   11.0: ' Más de 10 SM ($21,913 o más mensuales)',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'S13': {988888.0: ' NS', 999999.0: ' NC'},
#  'S14': {1.0: ' De 0 a 2 SM ($ 0 hasta $4,382 al mes)',
#   2.0: ' De 2 a 4 SM ($ 4,383 hasta $8,765 al mes)',
#   3.0: ' De 4 a 6 SM ($ 8,766 hasta $13,147 al mes)',
#   4.0: ' De 6 a 8 SM ($ 13,147 hasta $17,529 al mes)',
#   5.0: ' De 8 a 10 SM ($ 17,530 hasta $19,721 al mes)',
#   6.0: ' De 10 a 12 SM ($ 19,722 hasta $26,294 al mes)',
#   7.0: ' De 12 a 14 SM ($ 26,295 hasta $30,677 al mes)',
#   8.0: ' De 14 a 16 SM ($ 30,678 hasta $35,059 al mes)',
#   9.0: ' De 16 a 18 SM ($ 35,059 hasta $39,441 al mes)',
#   10.0: ' De 18 a 20 SM ($ 39,442 hasta $43,824 al mes)',
#   11.0: ' Más de 20 SM ($43,825 o más mensuales)',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'total2': {1.0: 'Total Nacional'},
#  'sexo': {1.0: ' Hombre', 2.0: ' Mujer'},
#  'edad': {1.0: 'De 15 a 24 años',
#   2.0: 'De 25 a 34 años',
#   3.0: 'De 35 a 44 años',
#   4.0: 'De 45 a 54 años',
#   5.0: 'De 55 a 64 años',
#   6.0: '65 años y más'},
#  'escol': {1.0: 'Ninguno',
#   3.0: 'Primaria',
#   4.0: 'Secundaria',
#   5.0: 'Preparatoria o Bachillerato',
#   6.0: 'Licenciatura o Posgrado'},
#  'region': {1.0: 'Norte',
#   2.0: 'Centro-Occidente',
#   3.0: 'Centro',
#   4.0: 'Sur-Sureste'},
#  'ing_ind': {1.0: 'De $1 a $4,382 (Hasta 2 SM)',
#   2.0: 'De $4,383 a $8,765 (Más de 2 Hasta 4 SM)',
#   3.0: 'Más de $8,765 (Más de 4 SM)',
#   988888.0: 'NS',
#   999999.0: 'NC'},
#  'ing_fam': {1.0: 'Menos de $4,383 (Hasta 2 SM)',
#   2.0: 'De $4,383 a $8,765 (Más de 2 Hasta 4 SM)',
#   3.0: 'De $8,766 a $13,147 (Más de 4 Hasta 6 SM)',
#   4.0: 'Más de $13,147 (Más de 6 SM)',
#   988888.0: 'NS',
#   999999.0: 'NC'},
#  'partido_pol': {1.0: ' PAN',
#   2.0: ' PRD',
#   3.0: ' PRI',
#   4.0: ' PT',
#   5.0: ' PVEM',
#   6.0: ' Convergencia',
#   7.0: ' Nueva Alianza (Panal)',
#   8.0: ' MORENA',
#   9.0: ' Partido Encuentro Social (PES)',
#   10.0: ' Otro',
#   11.0: ' Ninguno',
#   98.0: ' NS',
#   99.0: ' NC'},
#  'est_civil': {1.0: 'Unión libre / Casado',
#   2.0: 'Separado / Divorciado / Viudo',
#   3.0: 'Soltero'},
#  'cond_act': {1.0: 'Sí trabajó', 2.0: 'No trabajó'}}
